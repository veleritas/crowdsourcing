# %% [markdown]
# ### Analysis of Crowdflower job #705001: Overall performance on broad semantic relationships

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from src.summary import data_summary

# %% [markdown]
# How did the crowd do on the entire dataset?

# %%
settings = {
    "data_subset": "all",
    "min_accuracy": 0.0,
    "max_accuracy": 1.0,
    "link_type": "all",
    "loc": "/home/toby/crowdsourcing/extract_relationships/results/analysis",
    "fname": "705001_full_with_untrusted_and_unfinished.csv",
    "show_raw": False,
    "combine_pos_and_spec": False
}

data_summary(settings)
# Out:
# Distribution of matches with gold standard based on response rank:
# 0    40
# 1     3
# 2     1
# 3     0
# dtype: float64
#
# Total number of work units for this subset of data: 59
#
# Number of correct responses with respect to the rank of confidence score:
# 40.0/59 (67.7966101695%) work units had the correct answer in the top ranked position

# %% [markdown]
# The top choice selected by the crowd was the correct answer 67.79% of the time.

# %% [markdown]
# However, the gold standard questions presented in quiz mode are seen by a very different population of workers compared to the regular questions. Therefore we are more interested in the normal questions.

# %%
settings = {
    "data_subset": "normal",
    "min_accuracy": 0.7,
    "max_accuracy": 1.0,
    "link_type": "all",
    "loc": "/home/toby/crowdsourcing/extract_relationships/results/analysis",
    "fname": "705001_full_with_untrusted_and_unfinished.csv",
    "show_raw": False,
    "combine_pos_and_spec": False
}

data_summary(settings)
# Out:
# Distribution of matches with gold standard based on response rank:
# 0    31
# 1     4
# 2     0
# 3     0
# dtype: float64
#
# Total number of work units for this subset of data: 49
#
# Number of correct responses with respect to the rank of confidence score:
# 31.0/49 (63.2653061224%) work units had the correct answer in the top ranked position

# %% [markdown]
# We see that the top choice of the crowd was the correct answer 63.26% of the time.

# %% [markdown]
# Notice that most of the time, the correct answer is the top crowd choice. This is good, because it means we are capturing most of the signal by taking the top choice as the "final crowd answer".

# %% [markdown]
# However, this does not mean that the top crowd selected choice is always the correct answer. The data are only suggesting that people can agree on the correct answer.
