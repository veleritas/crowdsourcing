# %% [markdown]
# ### Analysis of Crowdflower job #705001: Performance of broad relationships on different semantic groups

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from src.summary import data_summary

# %% [markdown]
# Let's look at how the workers did on each of the five possible semantic groups:

# %%
settings = {
    "data_subset": "normal",
    "min_accuracy": 0.0,
    "max_accuracy": 1.0,
    "link_type": "disease/drug",
    "loc": "/home/toby/crowdsourcing/extract_relationships/results/analysis",
    "fname": "705001_full_with_untrusted_and_unfinished.csv",
    "show_raw": False,
    "combine_pos_and_spec": False
}

data_summary(settings)
# Out:
# Distribution of matches with gold standard based on response rank:
# 0    5
# 1    1
# 2    0
# 3    0
# dtype: float64
#
# Total number of work units for this subset of data: 10
#
# Number of correct responses with respect to the rank of confidence score:
# 5.0/10 (50.0%) work units had the correct answer in the top ranked position

# %%
settings = {
    "data_subset": "normal",
    "min_accuracy": 0.0,
    "max_accuracy": 1.0,
    "link_type": "disease/drug",
    "loc": "/home/toby/crowdsourcing/extract_relationships/results/analysis",
    "fname": "705001_full_with_untrusted_and_unfinished.csv",
    "show_raw": False,
    "combine_pos_and_spec": True
}

data_summary(settings)
# Out:
# Distribution of matches with gold standard based on response rank:
# 0    5
# 1    2
# 2    0
# dtype: float64
#
# Total number of work units for this subset of data: 10
#
# Number of correct responses with respect to the rank of confidence score:
# 5.0/10 (50.0%) work units had the correct answer in the top ranked position
# /home/toby/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:389: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
#   self.obj[item] = s

# %% [markdown]
# The crowd seems to have done pretty poorly on the disease/drug links. Combining the positive and speculative answers does not seem to help either.

# %%
settings = {
    "data_subset": "normal",
    "min_accuracy": 0.0,
    "max_accuracy": 1.0,
    "link_type": "gene or protein/disease",
    "loc": "/home/toby/crowdsourcing/extract_relationships/results/analysis",
    "fname": "705001_full_with_untrusted_and_unfinished.csv",
    "show_raw": False,
    "combine_pos_and_spec": False
}

data_summary(settings)
# Out:
# Distribution of matches with gold standard based on response rank:
# 0    7
# 1    0
# 2    0
# 3    0
# dtype: float64
#
# Total number of work units for this subset of data: 10
#
# Number of correct responses with respect to the rank of confidence score:
# 7.0/10 (70.0%) work units had the correct answer in the top ranked position

# %%
settings = {
    "data_subset": "normal",
    "min_accuracy": 0.0,
    "max_accuracy": 1.0,
    "link_type": "gene or protein/disease",
    "loc": "/home/toby/crowdsourcing/extract_relationships/results/analysis",
    "fname": "705001_full_with_untrusted_and_unfinished.csv",
    "show_raw": False,
    "combine_pos_and_spec": True
}

data_summary(settings)
# Out:
# Distribution of matches with gold standard based on response rank:
# 0    8
# 1    1
# 2    0
# dtype: float64
#
# Total number of work units for this subset of data: 10
#
# Number of correct responses with respect to the rank of confidence score:
# 8.0/10 (80.0%) work units had the correct answer in the top ranked position

# %% [markdown]
# For the gene/disease links, the crowd seems to do pretty well (70%). This is better than their overall score of around 60%. Combining positive and speculative also improves the performance a little bit.

# %%
settings = {
    "data_subset": "normal",
    "min_accuracy": 0.0,
    "max_accuracy": 1.0,
    "link_type": "gene variant/disease",
    "loc": "/home/toby/crowdsourcing/extract_relationships/results/analysis",
    "fname": "705001_full_with_untrusted_and_unfinished.csv",
    "show_raw": False,
    "combine_pos_and_spec": False
}

data_summary(settings)
# Out:
# Distribution of matches with gold standard based on response rank:
# 0    8
# 1    1
# 2    0
# 3    0
# dtype: float64
#
# Total number of work units for this subset of data: 10
#
# Number of correct responses with respect to the rank of confidence score:
# 8.0/10 (80.0%) work units had the correct answer in the top ranked position

# %%
settings = {
    "data_subset": "normal",
    "min_accuracy": 0.0,
    "max_accuracy": 1.0,
    "link_type": "gene variant/disease",
    "loc": "/home/toby/crowdsourcing/extract_relationships/results/analysis",
    "fname": "705001_full_with_untrusted_and_unfinished.csv",
    "show_raw": False,
    "combine_pos_and_spec": True
}

data_summary(settings)
# Out:
# Distribution of matches with gold standard based on response rank:
# 0    8
# 1    1
# 2    0
# dtype: float64
#
# Total number of work units for this subset of data: 10
#
# Number of correct responses with respect to the rank of confidence score:
# 8.0/10 (80.0%) work units had the correct answer in the top ranked position

# %% [markdown]
# No change in performance is seen when we combine positive and speculative. This suggests that the crowd is not being stuck on the difference between the two. Performance for gene variant/disease relationships also seems pretty good.

# %%
settings = {
    "data_subset": "normal",
    "min_accuracy": 0.0,
    "max_accuracy": 1.0,
    "link_type": "gene or protein/drug",
    "loc": "/home/toby/crowdsourcing/extract_relationships/results/analysis",
    "fname": "705001_full_with_untrusted_and_unfinished.csv",
    "show_raw": False,
    "combine_pos_and_spec": False
}

data_summary(settings)
# Out:
# Distribution of matches with gold standard based on response rank:
# 0    6
# 1    0
# 2    1
# 3    0
# dtype: float64
#
# Total number of work units for this subset of data: 10
#
# Number of correct responses with respect to the rank of confidence score:
# 6.0/10 (60.0%) work units had the correct answer in the top ranked position

# %%
settings = {
    "data_subset": "normal",
    "min_accuracy": 0.0,
    "max_accuracy": 1.0,
    "link_type": "gene or protein/drug",
    "loc": "/home/toby/crowdsourcing/extract_relationships/results/analysis",
    "fname": "705001_full_with_untrusted_and_unfinished.csv",
    "show_raw": False,
    "combine_pos_and_spec": True
}

data_summary(settings)
# Out:
# Distribution of matches with gold standard based on response rank:
# 0    8
# 1    0
# 2    0
# dtype: float64
#
# Total number of work units for this subset of data: 10
#
# Number of correct responses with respect to the rank of confidence score:
# 8.0/10 (80.0%) work units had the correct answer in the top ranked position

# %% [markdown]
# For the gene/drug relationships, it is concerning that one of the correct answers shows up as the third ranked choice of the crowd for that question. However, if we combine positive and speculative, the performance shoots up to 80%. Therefore it seems the crowd is confused about the positive/speculative relationships for the gene/drug subset.

# %%
settings = {
    "data_subset": "normal",
    "min_accuracy": 0.0,
    "max_accuracy": 1.0,
    "link_type": "gene variant/drug",
    "loc": "/home/toby/crowdsourcing/extract_relationships/results/analysis",
    "fname": "705001_full_with_untrusted_and_unfinished.csv",
    "show_raw": False,
    "combine_pos_and_spec": False
}

data_summary(settings)
# Out:
# Distribution of matches with gold standard based on response rank:
# 0    6
# 1    0
# 2    0
# 3    0
# dtype: float64
#
# Total number of work units for this subset of data: 9
#
# Number of correct responses with respect to the rank of confidence score:
# 6.0/9 (66.6666666667%) work units had the correct answer in the top ranked position

# %% [markdown]
# Overall the performance across the individual groups seems to be pretty consistent. There is some variation in the performance, but I think that it is likely that an improved understanding of what we want from these four relationships (through better instructions) will be able to improve the performance across all group. As in, I don't think the crowd is getting hung up on the definitions of the terms or anything. We will be able to see their understanding of the questions based on their performance on the deep semantics.
