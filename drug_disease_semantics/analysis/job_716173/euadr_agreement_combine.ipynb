# %% [markdown]
# ## Agreement with EU-ADR for job 716713 when positive and speculative choices are combined

# %% [markdown]
# 2015-04-23 Tong Shu Li

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from itertools import islice

# %%
import sys
sys.path.append("/home/toby/crowdsourcing/drug_disease_semantics/src/")

from filter_data import filter_data
from aggregate_results import aggregate_results
from true_relation_type import get_euadr_relation_type
from get_orig_problem import get_orig_problem

# %%
sys.path.append("/home/toby/global_util/")
from file_util import read_file

# %%
settings = {
    "loc": "/home/toby/crowdsourcing/drug_disease_semantics/data/",
    "fname": "job_716713_full_with_untrusted_and_unfinished.tsv",
    "data_subset": "normal",
    "min_accuracy": 0.7,
    "max_accuracy": 1.0,
    "id_column": "pub_rel_id",
    "categories": [["positive", "speculative"], ["negative"], ["false"]]
}

# %%
raw_data = filter_data(settings)

# %%
euadr_answer = get_euadr_relation_type(settings)

# %%
len(raw_data)
# Out:
# 1022

# %%
def create_match(gold_std_answer):
    def match(identifier, crowd_choice):
        return int(crowd_choice == gold_std_answer[identifier])
    
    return match

# %%
match_obj = create_match(euadr_answer)

# %%
results = aggregate_results("pub_rel_id", "broad_rel_type", raw_data, match_obj)

# %%
def determine_matches(results):
    matches = []
    mismatches = []
    for rel_id, group in results.groupby("pub_rel_id"):
        if group.iloc[0]["match"] == 1:
            matches.append(rel_id)
        else:
            mismatches.append(rel_id)
            
    return (matches, mismatches)

# %%
matches, mismatches = determine_matches(results)

# %%
def broad_reltype_summary(settings):
    raw_data = filter_data(settings)

    true_relation_type = get_euadr_relation_type(settings)

    match_obj = create_match(true_relation_type)

    results = aggregate_results("pub_rel_id", "broad_rel_type", raw_data, match_obj)

#--------------------------------------------------------------------
    ans = pd.Series([0] * 4)
    for unit_id, group in results.groupby(settings["id_column"]):
        temp = list(group["match"])
        ans = ans.add(pd.Series(temp), fill_value = 0)

    num_work_units = len(results[settings["id_column"]].unique())

    print "Distribution of matches with gold standard based on response rank:\n{0}".format(ans)
    print
    print ("Total number of work units for this subset of data: {0}".
        format(num_work_units))
    print
    print "Number of correct responses with respect to the rank of confidence score:"
    print ("{0}/{1} ({2}%) work units had the correct answer in the top ranked position".
           format(ans[0], num_work_units, ans[0]/num_work_units * 100))

    graph = ans.plot(kind = "bar")
    graph.set_xlabel("Rank of the correct choice according to the crowd")
    graph.set_ylabel("Number of work units where the crowd chosen top answer\n"\
        "matched that of the gold standard")

# %%
broad_reltype_summary(settings)
# Out:
# Distribution of matches with gold standard based on response rank:
# 0    173
# 1     19
# 2      2
# 3      0
# dtype: float64
#
# Total number of work units for this subset of data: 244
#
# Number of correct responses with respect to the rank of confidence score:
# 173.0/244 (70.9016393443%) work units had the correct answer in the top ranked position

# %%
orig_problem = get_orig_problem("pub_rel_id", raw_data)

# %%
def sort_by_conf(work_units):
    """
    Sort the work units in decreasing order of agreement
    for the top chosen crowd answer.
    """
    temp = []
    for rel_id in work_units:
        group = results.query("pub_rel_id == '{0}'".format(rel_id))
        temp.append((rel_id, group.iloc[0]["percent_agree"]))
        
    temp = sorted(temp, key = lambda x: x[1], reverse = True)
    return [val[0] for val in temp]

# %%
matches = sort_by_conf(matches)

# %%
mismatches = sort_by_conf(mismatches)

# %%
loc = "/home/toby/crowdsourcing/drug_disease_semantics/data/"

pub_to_raw_mapping = dict()
for line in islice(read_file(loc + "raw_to_toby_mapping.txt"), 1, None):
    pub_rel_id, raw_rel_id, num_agree = line.split('|')
    pub_to_raw_mapping[pub_rel_id] = (raw_rel_id, int(num_agree))

# %%
def summary(work_units):
    for identifier in work_units:
        subset = results.query("pub_rel_id == '{0}'".format(identifier))
        
        unit_id = raw_data.query("pub_rel_id == '{0}'".format(identifier)).iloc[0]["_unit_id"]
        
        print "Unit id: {0}".format(unit_id)
        print
        print "EU-ADR answer:", euadr_answer[identifier]
        print "Experts agree: {0}/3".format(pub_to_raw_mapping[identifier][1])
        print
        print subset
        print
        print orig_problem[identifier][3]
        print
        print "============================================================"

# %%
summary(mismatches)
# Out:
# Unit id: 706124689
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#        pub_rel_id        broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_1  positive_speculative      2.4251          3              1
#
#    match
# 0      0
#
# [[Cardiovascular thromboembolic adverse effects]] associated with [[cyclooxygenase]]-2 selective inhibitors and nonselective antiinflammatory drugs.
#
# ============================================================
# Unit id: 707779908
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_116  positive_speculative        2.85          3
#
#    percent_agree  match
# 0              1      0
#
# [[Long-term immunomodulatory drug]] (IMD) treatment is now common in [[multiple sclerosis]] (MS).
#
# ============================================================
# Unit id: 707780025
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_119       negative      2.5126          3              1
#
#    match
# 0      0
#
# In ER+ breast tumors, 2.5 mg/d [[tibolone]] given for 14 days has no significant effect on [[tumor]] cell proliferation.
#
# ============================================================
# Unit id: 706124819
#
# EU-ADR answer: false
# Experts agree: 1/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_121  positive_speculative      2.4848          3
#
#    percent_agree  match
# 0              1      0
#
# Exposure to Benzodiazepines ([[BZD]]) during foetal life has been suggested to contribute to neonatal morbidity and some [[congenital malformations]], for example, orofacial clefts.
#
# ============================================================
# Unit id: 706124752
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_122  positive_speculative       2.397          3
#
#    percent_agree  match
# 0              1      0
#
# Exposure to [[Benzodiazepines]] (BZD) during foetal life has been suggested to contribute to neonatal morbidity and some congenital malformations, for example, [[orofacial clefts]].
#
# ============================================================
# Unit id: 706124751
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_123  positive_speculative      5.7152          7
#
#    percent_agree  match
# 0              1      0
#
# Exposure to [[Benzodiazepines]] (BZD) during foetal life has been suggested to contribute to neonatal morbidity and some [[congenital malformations]], for example, orofacial clefts.
#
# ============================================================
# Unit id: 706124900
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_124  positive_speculative        2.85          3
#
#    percent_agree  match
# 0              1      0
#
# Maternal use of [[BZD]] and/or HBRA may increase the risk for [[preterm birth]] and low birth weight and cause neonatal symptoms, but does not appear to have a strong teratogenic potential.
#
# ============================================================
# Unit id: 706987913
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_125  positive_speculative      2.4833          3
#
#    percent_agree  match
# 0              1      0
#
# Exposure to Benzodiazepines ([[BZD]]) during foetal life has been suggested to contribute to neonatal morbidity and some congenital malformations, for example, [[orofacial clefts]].
#
# ============================================================
# Unit id: 706124921
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_129  positive_speculative      2.5421          3
#
#    percent_agree  match
# 0              1      0
#
# After two years [[ecstasy]] users showed persistent [[deficits on verbal fluency]], working memory and processing speed.
#
# ============================================================
# Unit id: 706124922
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_130  positive_speculative      2.6836          3
#
#    percent_agree  match
# 0              1      0
#
# When ecstasy users were classified according to lifetime use of [[ecstasy]], the more severe users (more than 100 tablets) showed additional [[deficits on episodic memory]].
#
# ============================================================
# Unit id: 706124800
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_135  positive_speculative      2.5666          3
#
#    percent_agree  match
# 0              1      0
#
# Sustained virologic response (SVR) rates of 50%-60% have been achieved in patients with [[chronic hepatitis C genotype 4]] treated with [[peginterferon]] plus ribavirin.
#
# ============================================================
# Unit id: 706124691
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_138  positive_speculative      3.2892          4
#
#    percent_agree  match
# 0              1      0
#
# Exposure to [[radioisotopes of metals and halogen elements]] occurring in medical practice may cause [[spontaneous abortions]].
#
# ============================================================
# Unit id: 706124705
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_140  positive_speculative      2.4892          3
#
#    percent_agree  match
# 0              1      0
#
# Women exposed to [[radioisotopes]] experienced at least a threefold higher rate of [[spontaneous abortions]] than those exposed to X-ray (OR = 3.68, 95% CI = 1.39-9.74, P < 0.01).
#
# ============================================================
# Unit id: 706124743
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_16  positive_speculative       3.416          4
#
#    percent_agree  match
# 0              1      0
#
# Review of recent results of [[montelukast]] use as a monotherapy in children with [[mild asthma]].
#
# ============================================================
# Unit id: 706124914
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_162  positive_speculative      2.3596          3
#
#    percent_agree  match
# 0              1      0
# There was an estimated 50% excess risk of [[malignancy]] among [[methotrexate]]-exposed RA patients relative to the general population (SIR 1.5, 95% confidence interval [95% CI] 1.2-1.9), with a 3-fold increase in melanoma (SIR 3.0, 95% CI 1.2-6.2), a 5-fold increase in non-Hodgkin's lymphoma (SIR 5.1, 95% CI 2.2-10.0), and an almost 3-fold increase in lung cancer (SIR 2.9, 95% CI 1.6-4.8).
#
# ============================================================
# Unit id: 706124866
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_17  positive_speculative      2.5421          3
#
#    percent_agree  match
# 0              1      0
#
# This article reviewed recent results from randomized, double-blind studies of children with [[mild asthma]] treated with [[montelukast]], a leukotriene receptor antagonist that is approved for the treatment of asthma and allergic rhinitis in children and adults.
#
# ============================================================
# Unit id: 706124903
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_171  positive_speculative      2.4833          3
#
#    percent_agree  match
# 0              1      0
#
# [[Recombinant hirudin]] is used as an alternative anticoagulant, particularly in patients with [[heparin-induced thrombocytopenia type II]].
#
# ============================================================
# Unit id: 706124725
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_174  positive_speculative       2.397          3
#
#    percent_agree  match
# 0              1      0
#
# Children with prosthetic cardiac valves and other invasive mechanical devices that direct blood flow require [[anticoagulant]] medication for prevention of [[thrombosis]].
#
# ============================================================
# Unit id: 706124864
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_182       negative      2.3596          3              1
#
#    match
# 0      0
#
# This once-weekly regimen is generally well tolerated, and studies to date have reported that [[epoetin beta]] has a neutral effect on survival of patients with [[cancer]].
#
# ============================================================
# Unit id: 706124781
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_183  positive_speculative      3.2578          4
#
#    percent_agree  match
# 0              1      0
#
# [[Epoetin beta]] once weekly: review of its efficacy and safety in patients with chemotherapy-induced [[anemia]].
#
# ============================================================
# Unit id: 706124862
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_199       negative      2.6092          3              1
#
#    match
# 0      0
#
# Compared with both diuretics and contemporary agents, [[amlodipine]] decreases cardiovascular events to a similar or greater extent without evidence for increased coronary heart disease, gastrointestinal bleeding or [[cancer]].
#
# ============================================================
# Unit id: 706124872
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#        pub_rel_id        broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_2  positive_speculative      2.5421          3              1
#
#    match
# 0      0
#
# [[Cardiovascular thromboembolic adverse effects]] associated with cyclooxygenase-2 selective inhibitors and [[nonselective antiinflammatory drugs]].
#
# ============================================================
# Unit id: 706124808
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_200  positive_speculative      5.7219          7
#
#    percent_agree  match
# 0              1      0
#
# [[Dihydropyridine calcium channel antagonists]] may exert effects that protect against [[stroke]] that are independent of their blood pressure-lowering mechanism.
#
# ============================================================
# Unit id: 706124826
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_205  positive_speculative       7.415          9
#
#    percent_agree  match
# 0              1      0
#
# [[Dihydropyridine calcium channel antagonists]] have several noteworthy attributes that merit consideration in the management of [[hypertension]].
#
# ============================================================
# Unit id: 706124824
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_219  positive_speculative      2.5873          3
#
#    percent_agree  match
# 0              1      0
#
# The established [[teratogenicity]] of [[antiepileptic drugs]] raises important issues in women of child-bearing age.
#
# ============================================================
# Unit id: 706124867
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_227  positive_speculative      2.6836          3
#
#    percent_agree  match
# 0              1      0
#
# Two years after initiating [[SRL]], she presented complaints of progressive dyspnoea, [[nonproductive cough]], chest pain and low-grade fever of 1 month duration.
#
# ============================================================
# Unit id: 706124718
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_228  positive_speculative      2.4892          3
#
#    percent_agree  match
# 0              1      0
#
# Two years after initiating [[SRL]], she presented complaints of progressive dyspnoea, nonproductive cough, [[chest pain]] and low-grade fever of 1 month duration.
#
# ============================================================
# Unit id: 706124708
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_229  positive_speculative      2.6209          3
#
#    percent_agree  match
# 0              1      0
#
# The only patient with [[leucoencephalopathy]] showed improved neurologic status after [[SRL]] conversion.
#
# ============================================================
# Unit id: 706124896
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_233  positive_speculative        2.85          3
#
#    percent_agree  match
# 0              1      0
#
# The reasons for conversion were calcineurin inhibitors (CNI) nephrotoxicity (n = 24; 73%), severe neurotoxicity owing to CNI (n = 1; 3%), severe and/or recurrent acute rejection episodes (n = 7; 21%), [[gastrointestinal]] (GI) side effects of [[mycophenolate mofetil]] (MMF; n = 5; 15%), and hyperglycemia (n = 4; 12%).
#
# ============================================================
# Unit id: 706124741
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_237  positive_speculative      2.7424          3
#
#    percent_agree  match
# 0              1      0
# Furthermore, the efficacy of the new generation of [[antiepileptic agents]] in the prophylaxis of [[perioperative seizures]] has not been assessed so far.
#
# ============================================================
# Unit id: 706124790
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_239  positive_speculative      2.4745          3
#
#    percent_agree  match
# 0              1      0
#
# We tested the hypothesis that oral beclomethasone dipropionate ([[BDP]]) would control [[gastrointestinal graft-versus-host disease]] (GVHD) in patients with anorexia, vomiting, and diarrhea.
#
# ============================================================
# Unit id: 707284767
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_54  positive_speculative       2.609          3
#
#    percent_agree  match
# 0              1      0
#
# Past use of [[antimetabolites]], T-cell inhibitors, alkylating agents, and other immunosuppressives is ascertained from medical records of approximately 9,250 [[ocular inflammation]] patients at five tertiary centers over up to 30 years.
#
# ============================================================
# Unit id: 706124898
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_57  positive_speculative      3.3592          4
#
#    percent_agree  match
# 0              1      0
#
# Past use of antimetabolites, T-cell inhibitors, [[alkylating agents]], and other immunosuppressives is ascertained from medical records of approximately 9,250 [[ocular inflammation]] patients at five tertiary centers over up to 30 years.
#
# ============================================================
# Unit id: 706124920
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_58  positive_speculative      2.6092          3
#
#    percent_agree  match
# 0              1      0
#
# Past use of antimetabolites, [[T-cell inhibitors]], alkylating agents, and other immunosuppressives is ascertained from medical records of approximately 9,250 [[ocular inflammation]] patients at five tertiary centers over up to 30 years.
#
# ============================================================
# Unit id: 706124690
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_67  positive_speculative      3.5426          4
#
#    percent_agree  match
# 0              1      0
#
# An inverse trend was observed between dose and multiplicity of [[colonic dysplasias]] in all drug-treated groups (P = 0.03), with animals receiving 75 mg/kg 5-ASA exhibiting 56% of the number of dysplasias of the AOM/[[DSS]] controls (mean +/- SEM: 7.6 +/- 1.4 and 13.6 +/- 2.7, respectively).
#
# ============================================================
# Unit id: 706124834
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_75  positive_speculative      2.5598          3
#
#    percent_agree  match
# 0              1      0
#
# The chemopreventive activity of 5-ASA was evaluated in the Swiss Webster model of [[azoxymethane]] (AOM)/dextran sulfate sodium (DSS)-induced [[colitis-associated neoplasia]].
#
# ============================================================
# Unit id: 706124711
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_76  positive_speculative      2.7424          3
#
#    percent_agree  match
# 0              1      0
#
# Administration of 75 mg/kg [[5-ASA]] decreased both the mean multiplicity of flat dysplasias (1.8 +/- 0.4 for drug-treated versus 5.6 +/- 1.2 for AOM/DSS control) and the burden of [[polypoid dysplasias]] (tumor burden: 6.7 +/- 2.7 for drug-treated versus 14.9 +/- 3.9 units for AOM/DSS controls) significantly (P = 0.002 and 0.04, respectively).
#
# ============================================================
# Unit id: 706124745
#
# EU-ADR answer:
#  false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_80  positive_speculative      2.6322          3
#
#    percent_agree  match
# 0              1      0
#
# The chemopreventive activity of 5-ASA was evaluated in the Swiss Webster model of azoxymethane (AOM)/dextran sulfate sodium ([[DSS]])-induced [[colitis-associated neoplasia]].
#
# ============================================================
# Unit id: 706124729
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_86  positive_speculative      4.9747          6
#
#    percent_agree  match
# 0              1      0
#
# Recently, there have been reports of [[noninfectious granulomatous syndromes]] in patients receiving [[etanercept]] for a variety of diseases.
#
# ============================================================
# Unit id: 706124685
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_87  positive_speculative      2.6209          3
#
#    percent_agree  match
# 0              1      0
#
# Development of [[sarcoidosis]] in [[etanercept]]-treated rheumatoid arthritis patients.
#
# ============================================================
# Unit id: 706124909
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_88  positive_speculative      2.4148          3
#
#    percent_agree  match
# 0              1      0
#
# Development of sarcoidosis in [[etanercept]]-treated [[rheumatoid arthritis]] patients.
#
# ============================================================
# Unit id: 706988916
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_91  positive_speculative      2.5421          3
#
#    percent_agree  match
# 0              1      0
#
# [[BiRD]] (Biaxin [clarithromycin]/Revlimid [lenalidomide]/dexamethasone) combination therapy results in high complete- and overall-response rates in treatment-naive symptomatic [[multiple myeloma]].
#
# ============================================================
# Unit id: 706124865
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_92  positive_speculative      2.5879          3
#
#    percent_agree  match
# 0              1      0
#
# This trial determined the safety and efficacy of the combination regimen clarithromycin (Biaxin), lenalidomide (Revlimid), and dexamethasone ([[BiRD]]) as first-line therapy for [[multiple myeloma]].
#
# ============================================================
# Unit id: 706124699
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_94  positive_speculative      3.2892          4
#
#    percent_agree  match
# 0              1      0
#
# Recent prospective studies from Europe suggest the use of intracameral [[antibiotics]] for prophylaxis of [[endophthalmitis]], although the studies did not make a comparison with the most common United States prophylaxis techniques.
#
# ============================================================
# Unit id: 706124810
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_60  positive_speculative      5.0829          6
# 0  drug_disease_60                 false      0.8333          1
#
#    percent_agree  match
# 1       0.859149      0
# 0       0.140851      1
#
# Information from the SITE Cohort Study should clarify whether use of these [[immunosuppressive drugs]] for [[ocular inflammation]] increases the risk of mortality and fatal cancer.
#
# ============================================================
# Unit id: 706124838
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_235  positive_speculative      3.4438          4
# 0  drug_disease_235                 false      0.8000          1
#
#    percent_agree  match
# 1        0.81149      0
# 0        0.18851      1
#
# Our data showed that oxcarbazepine can be a good alternative to traditional [[antiepileptic agents]] in the prevention of [[perioperative seizures]] being efficacy, ease of use (rapid titration in 3 days, not requiring close plasma concentration monitoring) and good tolerability (no major side effects during titration and during the first postoperative week) the key factors.
#
# ============================================================
# Unit id: 706124746
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#        pub_rel_id        broad_rel_type  conf_score  num_votes  percent_agree  \
# 1  drug_disease_9  positive_speculative      2.7655          3       0.775628
# 0  drug_disease_9                 false      0.8000          1       0.224372
#
#    match
# 1      0
# 0      1
#
# Gingival samples were collected from eight normal healthy individuals, eight patients with periodontitis, and eight patients with cyclosporin A ([[CsA]])-induced [[gingival overgrowth]].
#
# ============================================================
# Unit id: 706124717
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_132              negative      2.5025          3
# 1  drug_disease_132  positive_speculative      0.7273          1
#
#    percent_agree  match
# 0       0.774816      0
# 1       0.225184      0
#
# No significant differences were observed between FeSO4+citrate and [[NaFe-EDTA]] fortification, regarding mitigation of [[iron-deficiency anemia]] (IDA) or regarding CRP, growth, infections, or side-effects.
#
# ============================================================
# Unit id: 707286745
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 1  drug_disease_203       negative      2.7947          3       0.770314
# 0  drug_disease_203          false      0.8333          1       0.229686
#
#    match
# 1      0
# 0      1
#
# Compared with both diuretics and contemporary agents, [[amlodipine]] decreases cardiovascular events to a similar or greater extent without evidence for increased coronary heart disease, [[gastrointestinal bleeding]] or cancer.
#
# ============================================================
# Unit id: 706124754
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_120              negative      2.5509          3
# 1  drug_disease_120  positive_speculative      0.7692          1
#
#    percent_agree  match
# 0        0.76832      0
# 1        0.23168      0
#
# In [[ER+ breast tumors]], 2.5 mg/d [[tibolone]] given for 14 days has no significant effect on tumor cell proliferation.
#
# ============================================================
# Unit id: 706124842
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_143  positive_speculative      2.5901          3
# 0  drug_disease_143                 false      0.8000          1
#
#    percent_agree  match
# 1       0.764019      0
# 0       0.235981      1
#
# Primary outcomes were [[asthma exacerbations]] (AE) requiring systemic [[corticosteroids]] or hospitalization, life-threatening exacerbations and asthma-related deaths.
#
# ============================================================
# Unit id: 706124833
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_89  positive_speculative      2.3743          3
# 0  drug_disease_89                 false      0.7368          1
#
#    percent_agree  match
# 1       0.763171      0
# 0       0.236829      1
#
# The other developed [[erythema nodosum]] and a plaque lesion on the right arm after 1 year of [[etanercept]].
#
# ============================================================
# Unit id: 706124788
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 2  drug_disease_173  positive_speculative      5.5519          7
# 0  drug_disease_173                 false      0.9412          1
# 1  drug_disease_173              negative      0.8077          1
#
#    percent_agree  match
# 2       0.760451      0
# 0       0.128917      1
# 1       0.110632      0
# Dental surgery for these children has historically consisted of decreasing and/or discontinuing the oral [[anticoagulant]] and instituting heparin therapy prior to the planned dental procedure, which can result in [[thromboembolism]] and increased morbidity and mortality.
#
# ============================================================
# Unit id: 706124888
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_134              negative      2.7515          3
# 1  drug_disease_134  positive_speculative      0.9167          1
#
#    percent_agree  match
# 0       0.750095      0
# 1       0.249905      0
#
# No significant differences were observed between [[FeSO4]]+citrate and NaFe-EDTA fortification, regarding mitigation of iron-deficiency anemia (IDA) or regarding CRP, growth, [[infections]], or side-effects.
#
# ============================================================
# Unit id: 706124873
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_198  positive_speculative      2.7189          3
# 0  drug_disease_198                 false      0.9091          1
#
#    percent_agree  match
# 1       0.749421      0
# 0       0.250579      1
#
# Long-term exposure to [[medium-dose glucocorticoid]] therapy associates with hypertension in patients with [[rheumatoid arthritis]].
#
# ============================================================
# Unit id: 706124832
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_133              negative      2.4848          3
# 1  drug_disease_133  positive_speculative      0.8333          1
#
#    percent_agree  match
# 0       0.748862      0
# 1       0.251138      0
#
# No significant differences were observed between [[FeSO4]]+citrate and NaFe-EDTA fortification, regarding mitigation of [[iron-deficiency anemia]] (IDA) or regarding CRP, growth, infections, or side-effects.
#
# ============================================================
# Unit id: 706124818
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_232  positive_speculative      2.2778          3
# 0  drug_disease_232                 false      0.8333          1
#
#    percent_agree  match
# 1       0.732153      0
# 0       0.267847      1
#
# The reasons for conversion were calcineurin inhibitors (CNI) nephrotoxicity (n = 24; 73%), severe neurotoxicity owing to CNI (n = 1; 3%), severe and/or recurrent acute rejection episodes (n = 7; 21%), [[gastrointestinal]] (GI) side effects of mycophenolate mofetil ([[MMF]]; n = 5; 15%), and hyperglycemia (n = 4; 12%).
#
# ============================================================
# Unit id: 706124695
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_61  positive_speculative      2.4670          3
# 0  drug_disease_61                 false      0.9231          1
#
#    percent_agree  match
# 1       0.727707      0
# 0       0.272293      1
#
# Past use of antimetabolites, T-cell inhibitors, alkylating agents, and other [[immunosuppressives]] is ascertained from medical records of approximately 9,250 [[ocular inflammation]] patients at five tertiary centers over up to 30 years.
#
# ============================================================
# Unit id: 706124886
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_152              negative      4.2158          5
# 1  drug_disease_152  positive_speculative      1.6071          2
#
#    percent_agree  match
# 0       0.724004      0
# 1       0.275996      1
#
# The study showed that ziprasidone was effective and tolerable, that use of [[ziprasidone]] was characterized by an absence of [[extrapyramidal symptoms]] and weight gain, and that no alterations in clinical laboratory tests occurred.
#
# ============================================================
# Unit id: 706124905
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 1  drug_disease_44       negative      2.4148          3       0.718862      0
# 0  drug_disease_44          false      0.9444          1       0.281138      0
#
# Interestingly, 5 microM of [[indomethacin-loaded nanocapsules]] was able to cause an antiproliferative effect without promoting necrosis in [[glioma]] cells.
#
# ============================================================
# Unit id: 706124703
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_31  positive_speculative      2.3042          3
# 0  drug_disease_31                 false      0.9286          1
#
#    percent_agree  match
# 1       0.712757      0
# 0       0.287243      1
#
# The aim of this study was to evaluate the effects of [[indomethacin-loaded nanocapsules]] and indomethacin ethyl ester-loaded nanocapsules on [[glioma]] cell lines.
#
# ============================================================
# Unit id: 707131026
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_18          false      4.0003          5       0.711886      0
# 1  drug_disease_18       negative      1.6190          2       0.288114      0
#
# A literature search of MEDLINE was conducted to gather relevant, English-language articles using search terms such as randomized controlled studies, double-blind studies, [[montelukast]], leukotriene receptor antagonist, pediatric asthma, [[mild asthma]], exercise-induced asthma, and bronchoconstriction.
#
# ============================================================
# Unit id: 706124839
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_109                 false      4.6922          6
# 1  drug_disease_109  positive_speculative      2.6316          3
#
#    percent_agree  match
# 0       0.640678      0
# 1       0.359322      1
#
# Similarly, the same regimen of posaconazole reduced invasive fungal infections (95% CI -9.7 to -2.5) and [[aspergillosis]] (CI not reported, p < 0.001) when compared with [[fluconazole]] and itraconazole in neutropenic patients.
#
# ============================================================
# Unit id: 706124783
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_37  positive_speculative      4.2679          5
# 0  drug_disease_37                 false      3.1163          4
#
#    percent_agree  match
# 1       0.577977      0
# 0       0.422023      1
#
# Selective cytotoxicity of indomethacin and [[indomethacin ethyl ester-loaded nanocapsules]] against [[glioma]] cell lines: an in vitro study.
#
# ============================================================
# Unit id: 706124753
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 2  drug_disease_131  positive_speculative      4.3622          5
# 1  drug_disease_131              negative      2.2781          3
# 0  drug_disease_131                 false      0.9333          1
#
#    percent_agree  match
# 2       0.575974      0
# 1       0.300795      0
# 0       0.123231      1
#
# No significant differences were observed between FeSO4+citrate and [[NaFe-EDTA]] fortification, regarding mitigation of iron-deficiency anemia (IDA) or regarding CRP, growth, [[infections]], or side-effects.
#
# ============================================================
# Unit id: 706124801
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_202              negative      4.2201          5
# 2  drug_disease_202  positive_speculative      2.5086          3
# 0  drug_disease_202                 false      0.7333          1
#
#    percent_agree  match
# 1       0.565545      0
# 2       0.336183      0
# 0       0.098271      1
#
# Compared with both diuretics and contemporary agents, [[amlodipine]] decreases cardiovascular events to a similar or greater extent without evidence for increased [[coronary heart disease]], gastrointestinal bleeding or cancer.
#
# ============================================================
# Unit id: 706124878
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 2  drug_disease_66  positive_speculative      4.0681          5
# 0  drug_disease_66                 false      2.4312          3
# 1  drug_disease_66              negative      0.8182          1
#
#    percent_agree  match
# 2       0.555941      0
# 0       0.332245      1
# 1       0.111814      0
#
# An inverse trend was observed between dose and multiplicity of colonic dysplasias in all drug-treated groups (P = 0.03), with animals receiving 75 mg/kg 5-ASA exhibiting 56% of the number of [[dysplasias]] of the AOM/[[DSS]] controls (mean +/- SEM: 7.6 +/- 1.4 and 13.6 +/- 2.7, respectively).
#
# ============================================================
# Unit id: 706124823
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#        pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 1  drug_disease_3       negative      4.1062          5       0.553009      0
# 0  drug_disease_3          false      3.3190          4       0.446991      1
# The frequency of PONV did not correlate to the amounts of [[alfentanil]], propofol, postoperative antiemetics consumed, or to female gender, non-smoking status, and history of PONV or [[motion sickness]].
#
# ============================================================
# Unit id: 706124813
#
# EU-ADR answer: negative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 2  drug_disease_222  positive_speculative      4.0048          5
# 1  drug_disease_222              negative      2.5113          3
# 0  drug_disease_222                 false      0.8077          1
#
#    percent_agree  match
# 2       0.546820      0
# 1       0.342896      1
# 0       0.110284      0
#
# Data of our study revealed an unexpected high rate of [[hypogonadism]] irrespective of [[cyclophosphamide]] use, and subclinical involvement of the testes by the vasculitis itself might be an alternative explanation.
#
# ============================================================
# Unit id: 706124749
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_68  positive_speculative      4.1262          5
# 0  drug_disease_68                 false      3.6420          4
#
#    percent_agree  match
# 1       0.531166      0
# 0       0.468834      1
#
# 5-aminosalicylic acid inhibits colitis-associated colorectal dysplasias in the mouse model of [[azoxymethane]]/dextran sulfate sodium-induced [[colitis]].
#
# ============================================================
# Unit id: 706124722
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#        pub_rel_id        broad_rel_type  conf_score  num_votes  percent_agree  \
# 1  drug_disease_4              negative      3.4528          4       0.452565
# 0  drug_disease_4                 false      3.3195          4       0.435093
# 2  drug_disease_4  positive_speculative      0.8571          1       0.112342
#
#    match
# 1      0
# 0      1
# 2      0
#
# The frequency of PONV did not correlate to the amounts of alfentanil, [[propofol]], postoperative antiemetics consumed, or to female gender, non-smoking status, and history of PONV or [[motion sickness]].
#
# ============================================================

# %%
summary(matches)
# Out:
# Unit id: 706124714
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#        pub_rel_id        broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_0  positive_speculative      2.5589          3              1
#
#    match
# 0      1
#
# Body height, weight and obesity increase the risk of [[venous thrombosis]], especially obesity in women using [[oral contraceptives]].
#
# ============================================================
# Unit id: 706124787
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_101  positive_speculative      2.3788          3
#
#    percent_agree  match
# 0              1      1
#
# The most common adverse effects associated with the use of [[posaconazole]] include headache, fever, [[nausea]], vomiting, and diarrhea.
#
# ============================================================
# Unit id: 706124869
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_102  positive_speculative      2.5879          3
#
#    percent_agree  match
# 0              1      1
#
# The most common adverse effects associated with the use of [[posaconazole]] include headache, fever, nausea, [[vomiting]], and diarrhea.
#
# ============================================================
# Unit id: 706124890
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_104  positive_speculative      2.6092          3
#
#    percent_agree  match
# 0              1      1
#
# Similarly, the same regimen of [[posaconazole]] reduced [[invasive fungal infections]] (95% CI -9.7 to -2.5) and aspergillosis (CI not reported, p < 0.001) when compared with fluconazole and itraconazole in neutropenic patients.
#
# ============================================================
# Unit id: 706124750
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_107  positive_speculative      3.4032          4
#
#    percent_agree  match
# 0              1      1
#
# At this time, [[posaconazole]] should probably be reserved for prophylaxis in patients at high risk for invasive fungal infection, as salvage therapy in refractory or [[resistant infections]], or for patients with intolerance to other therapies.
#
# ============================================================
# Unit id: 706124830
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_110  positive_speculative      2.3788          3
#
#    percent_agree  match
# 0              1      1
#
# [[Posaconazole]], in doses of 200 mg 3 times daily, reduced breakthrough invasive fungal infections (OR 0.30; 95% CI 0.12 to 0.71) and [[aspergillosis]] incidence (OR 0.31; 95% CI 0.13 to 0.75) in patients receiving hematopoietic stem-cell transplants compared with those receiving fluconazole.
#
# ============================================================
# Unit id: 706124885
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_112  positive_speculative      2.5879          3
#
#    percent_agree  match
# 0              1      1
#
# Posaconazole is noninferior to [[fluconazole]] for treatment of [[oropharyngeal candidiasis]] (95% CI -6.6 to 5.0), but necessity for this indication remains unclear, as many other treatment options exist.
#
# ============================================================
# Unit id: 706124821
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_113  positive_speculative      2.4848          3
#
#    percent_agree  match
# 0              1      1
#
# Posaconazole, in doses of 200 mg 3 times daily, reduced breakthrough [[invasive fungal infections]] (OR 0.30; 95% CI 0.12 to 0.71) and aspergillosis incidence (OR 0.31; 95% CI 0.13 to 0.75) in patients receiving hematopoietic stem-cell transplants compared with those receiving [[fluconazole]].
#
# ============================================================
# Unit id: 706124917
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_115  positive_speculative      7.3867          9
#
#    percent_agree  match
# 0              1      1
#
# While some beneficial neuromotor effects of succimer therapy were observed in the present study there remains several unanswered questions such as how long these effects will persist and how [[succimer]] therapy modifies lead-associated [[cerebellar deficits]] manifesting as perturbations in vestibular and/or proprioception systems for postural balance and functional locomotion.
#
# ============================================================
# Unit id: 706989513
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_117  positive_speculative      3.3022          4
#
#    percent_agree  match
# 0              1      1
#
# It is well known that [[tobacco smoke]] exposure is related to the risk of developing [[cardiovascular diseases]] and events.
#
# ============================================================
# Unit id: 706124836
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_118  positive_speculative      2.4745          3
#
#    percent_agree  match
# 0              1      1
#
# [[Tibolone]] is a selective tissue estrogenic activity regulator, approved for the treatment of [[vasomotor symptoms]] in postmenopausal women.
#
# ============================================================
# Unit id: 706124687
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_12  positive_speculative      5.0693          6
#
#    percent_agree  match
# 0              1      1
#
# These results suggest that CsA can modulate the expression of ET-1 in gingival fibroblasts and [[CsA]]-induced [[gingival overgrowth]].
#
# ============================================================
# Unit id: 706124702
#
# EU-ADR answer: negative
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_126       negative       2.397          3              1
#
#    match
# 0      1
#
# We found no evidence of impaired control of the carbohydrate and lipid metabolism or aggravation of [[vascular lesions]] during the two years an [[etonogestrel]] implant was used by diabetic women.
#
# ============================================================
# Unit id: 706124694
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_127  positive_speculative      6.8545          8
#
#    percent_agree  match
# 0              1      1
#
# [[Oritavancin]]: a new promising agent in the treatment of [[infections due to Gram-positive pathogens]].
#
# ============================================================
# Unit id: 706124772
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_128  positive_speculative      3.2931          4
#
#    percent_agree  match
# 0              1      1
# Our findings support that ecstasy use, or [[ecstasy/cannabis]] synergic effects, are responsible for the sub-clinical deficits observed in ecstasy polydrug users, and provides additional evidence for [[long-term cognitive impairment]] owing to ecstasy consumption in the context of polydrug use.
#
# ============================================================
# Unit id: 707282367
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_13          false      2.3596          3              1      1
#
# Gingival samples were collected from eight normal healthy individuals, eight patients with [[periodontitis]], and eight patients with cyclosporin A ([[CsA]])-induced gingival overgrowth.
#
# ============================================================
# Unit id: 706124785
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_136  positive_speculative      2.5078          3
#
#    percent_agree  match
# 0              1      1
#
# Adverse events were similar across treatment groups except for higher rates of [[anemia]] in the groups receiving [[ribavirin]].
#
# ============================================================
# Unit id: 706124764
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_137  positive_speculative      2.5078          3
#
#    percent_agree  match
# 0              1      1
#
# Sustained virologic response (SVR) rates of 50%-60% have been achieved in patients with [[chronic hepatitis C genotype 4]] treated with peginterferon plus [[ribavirin]].
#
# ============================================================
# Unit id: 706124877
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_139  positive_speculative      2.4833          3
#
#    percent_agree  match
# 0              1      1
#
# For exposure levels within standard recommended guidelines, [[radioisotopes]] are far more likely to play a role in the occurrence of [[spontaneous abortions]] than X-rays.
#
# ============================================================
# Unit id: 706124688
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_14  positive_speculative      2.4221          3
#
#    percent_agree  match
# 0              1      1
#
# Gingival samples were collected from eight normal healthy individuals, eight patients with periodontitis, and eight patients with [[cyclosporin A]] (CsA)-induced [[gingival overgrowth]].
#
# ============================================================
# Unit id: 706124719
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_141  positive_speculative      2.6754          3
#
#    percent_agree  match
# 0              1      1
#
# An open multicenter phase II trial of weekly [[docetaxel]] for [[advanced-stage non-small-cell lung cancer]] in elderly patients with significant comorbidity and/or poor performance status: The GFPC 02-02b study.
#
# ============================================================
# Unit id: 706124882
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_142  positive_speculative      2.4148          3
#
#    percent_agree  match
# 0              1      1
#
# Contrarily, [[LABA]] showed a significant increase in [[asthma-related deaths]] (Relative Risk=3.83; 95% CI, 1.21-12.14).
#
# ============================================================
# Unit id: 706124765
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_144  positive_speculative      2.4245          3
#
#    percent_agree  match
# 0              1      1
#
# Forty-one patients [30 males and 11 females, median age 47 years] consecutively diagnosed with [[PTCL]] received three courses of [[high-dose cyclophosphamide]] 2000 mg/m(2)/day, adriamycin 90 mg/m(2)/day, vincristine and prednisone alternating with three courses of etoposide, cisplatin, cytarabine and prednisone.
#
# ============================================================
# Unit id: 706124812
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_145  positive_speculative      2.5873          3
#
#    percent_agree  match
# 0              1      1
#
# Forty-one patients [30 males and 11 females, median age 47 years] consecutively diagnosed with [[PTCL]] received three courses of high-dose cyclophosphamide 2000 mg/m(2)/day, [[adriamycin]] 90 mg/m(2)/day, vincristine and prednisone alternating with three courses of etoposide, cisplatin, cytarabine and prednisone.
#
# ============================================================
# Unit id: 706124829
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_146  positive_speculative      2.5598          3
#
#    percent_agree  match
# 0              1      1
#
# Forty-one patients [30 males and 11 females, median age 47 years] consecutively diagnosed with [[PTCL]] received three courses of high-dose cyclophosphamide 2000 mg/m(2)/day, adriamycin 90 mg/m(2)/day, vincristine and prednisone alternating with three courses of etoposide, [[cisplatin]], cytarabine and prednisone.
#
# ============================================================
# Unit id: 706124820
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_147  positive_speculative      2.5873          3
#
#    percent_agree  match
# 0              1      1
#
# Forty-one patients [30 males and 11 females, median age 47 years] consecutively diagnosed with [[PTCL]] received three courses of high-dose cyclophosphamide 2000 mg/m(2)/day, adriamycin 90 mg/m(2)/day, vincristine and prednisone alternating with three courses of etoposide, cisplatin, cytarabine and [[prednisone]].
#
# ============================================================
# Unit id: 706124768
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_15  positive_speculative      5.6485          7
#
#    percent_agree  match
# 0              1      1
#
# The evidence suggests that [[montelukast]] is an effective monotherapy controller in children with [[mild asthma]].
#
# ============================================================
# Unit id: 707287260
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_150  positive_speculative        2.85          3
#
#    percent_agree  match
# 0              1      1
#
# Forty-one patients [30 males and 11 females, median age 47 years] consecutively diagnosed with [[PTCL]] received three courses of high-dose cyclophosphamide 2000 mg/m(2)/day, adriamycin 90 mg/m(2)/day, vincristine and prednisone alternating with three courses of [[etoposide]], cisplatin, cytarabine and prednisone.
#
# ============================================================
# Unit id: 706124740
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_151  positive_speculative       2.397          3
#
#    percent_agree  match
# 0              1      1
#
# Plasma [[ziprasidone]] levels ranged from 20 ng/mL to 160 ng/mL (mean: 75.8 ng/mL) and were significantly related to the improvement in [[negative symptoms]].
#
# ============================================================
# Unit id: 706124683
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_153  positive_speculative      2.6322          3
#
#    percent_agree  match
# 0              1      1
# Characteristic features of an [[inflammation]] induced by [[bevacizumab]] injection include an early onset with painless loss in VA mostly without conjunctival or ciliary injection.
#
# ============================================================
# Unit id: 706124794
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_154  positive_speculative      2.4745          3
#
#    percent_agree  match
# 0              1      1
#
# Administration of full-dose R-CHOP (rituximab/cyclophosphamide/doxorubicin/vincristine/[[prednisone]]) chemotherapy is important to maximize response in patients with intermediate-or [[high-grade non-Hodgkin lymphoma]] but might be difficult in older patients.
#
# ============================================================
# Unit id: 706124919
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_155  positive_speculative      2.5879          3
#
#    percent_agree  match
# 0              1      1
#
# Administration of full-dose R-CHOP ([[rituximab]]/cyclophosphamide/doxorubicin/vincristine/prednisone) chemotherapy is important to maximize response in patients with intermediate-or [[high-grade non-Hodgkin lymphoma]] but might be difficult in older patients.
#
# ============================================================
# Unit id: 706124759
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_156  positive_speculative      2.6209          3
#
#    percent_agree  match
# 0              1      1
#
# Administration of full-dose R-CHOP (rituximab/cyclophosphamide/[[doxorubicin]]/vincristine/prednisone) chemotherapy is important to maximize response in patients with intermediate-or [[high-grade non-Hodgkin lymphoma]] but might be difficult in older patients.
#
# ============================================================
# Unit id: 706124776
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_157  positive_speculative      2.3778          3
#
#    percent_agree  match
# 0              1      1
#
# Administration of full-dose R-CHOP (rituximab/[[cyclophosphamide]]/doxorubicin/vincristine/prednisone) chemotherapy is important to maximize response in patients with intermediate-or [[high-grade non-Hodgkin lymphoma]] but might be difficult in older patients.
#
# ============================================================
# Unit id: 706124786
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_158  positive_speculative      2.6744          3
#
#    percent_agree  match
# 0              1      1
#
# Administration of full-dose R-CHOP (rituximab/cyclophosphamide/doxorubicin/[[vincristine]]/prednisone) chemotherapy is important to maximize response in patients with intermediate-or [[high-grade non-Hodgkin lymphoma]] but might be difficult in older patients.
#
# ============================================================
# Unit id: 706124858
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_159  positive_speculative      2.6092          3
#
#    percent_agree  match
# 0              1      1
#
# Compared with the general population, [[methotrexate]]-treated RA patients have an increased incidence of melanoma, non-Hodgkin's lymphoma, and [[lung cancer]].
#
# ============================================================
# Unit id: 706124881
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_160  positive_speculative      2.3596          3
#
#    percent_agree  match
# 0              1      1
#
# Compared with the general population, [[methotrexate]]-treated RA patients have an increased incidence of [[melanoma]], non-Hodgkin's lymphoma, and lung cancer.
#
# ============================================================
# Unit id: 707218352
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_161  positive_speculative      2.5421          3
#
#    percent_agree  match
# 0              1      1
# Compared with the general population, [[methotrexate]]-treated RA patients have an increased incidence of melanoma, [[non-Hodgkin's lymphoma]], and lung cancer.
#
# ============================================================
# Unit id: 706124795
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_163  positive_speculative      2.5873          3
#
#    percent_agree  match
# 0              1      1
#
# There was an estimated 50% excess risk of malignancy among [[methotrexate]]-exposed RA patients relative to the general population (SIR 1.5, 95% confidence interval [95% CI] 1.2-1.9), with a 3-fold increase in melanoma (SIR 3.0, 95% CI 1.2-6.2), a 5-fold increase in [[non-Hodgkin's lymphoma]] (SIR 5.1, 95% CI 2.2-10.0), and an almost 3-fold increase in lung cancer (SIR 2.9, 95% CI 1.6-4.8).
#
# ============================================================
# Unit id: 706124835
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_165  positive_speculative      2.5078          3
#
#    percent_agree  match
# 0              1      1
#
# There was an estimated 50% excess risk of malignancy among [[methotrexate]]-exposed RA patients relative to the general population (SIR 1.5, 95% confidence interval [95% CI] 1.2-1.9), with a 3-fold increase in [[melanoma]] (SIR 3.0, 95% CI 1.2-6.2), a 5-fold increase in non-Hodgkin's lymphoma (SIR 5.1, 95% CI 2.2-10.0), and an almost 3-fold increase in lung cancer (SIR 2.9, 95% CI 1.6-4.8).
#
# ============================================================
# Unit id: 706124852
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_166  positive_speculative      2.5598          3
#
#    percent_agree  match
# 0              1      1
#
# Incidence of melanoma and other malignancies among [[rheumatoid arthritis]] patients treated with [[methotrexate]].
#
# ============================================================
# Unit id: 706124894
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_167  positive_speculative      2.6836          3
#
#    percent_agree  match
# 0              1      1
#
# To determine cancer risk in a cohort of 459 [[rheumatoid arthritis]] (RA) patients treated with [[methotrexate]] in community practice.
#
# ============================================================
# Unit id: 706124912
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_168  positive_speculative      2.4148          3
#
#    percent_agree  match
# 0              1      1
#
# To determine [[cancer]] risk in a cohort of 459 rheumatoid arthritis (RA) patients treated with [[methotrexate]] in community practice.
#
# ============================================================
# Unit id: 706124828
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_169  positive_speculative      2.5666          3
#
#    percent_agree  match
# 0              1      1
#
# Incidence of melanoma and other [[malignancies]] among rheumatoid arthritis patients treated with [[methotrexate]].
#
# ============================================================
# Unit id: 706124721
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_170  positive_speculative      2.4892          3
#
#    percent_agree  match
# 0              1      1
#
# Incidence of [[melanoma]] and other malignancies among rheumatoid arthritis patients treated with [[methotrexate]].
#
# ============================================================
# Unit id: 706124803
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_172  positive_speculative      2.5666          3
#
#    percent_agree  match
# 0              1      1
#
# Absence of villin predisposes mice to [[dextran sodium sulfate]]-induced [[colitis]] by promoting apoptosis.
#
# ============================================================
# Unit id: 706124727
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_176  positive_speculative      2.4221          3
#
#    percent_agree  match
# 0              1      1
#
# Finally, in non-small cell lung cancer (NSCLC) in patients' progressing on chemotherapy [[sutent]] was able to achieve a 10% response rate, a level of activity similar to those documented by other agents approved for [[lung cancer]].
#
# ============================================================
# Unit id: 706124793
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_177  positive_speculative      2.5078          3
#
#    percent_agree  match
# 0              1      1
#
# In several phase I/II/III studies, [[sutent]] was found to be effective as second and first line treatment in [[metastatic renal cell carcinoma]] (RCC).
#
# ============================================================
# Unit id: 706124911
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_178  positive_speculative      2.5879          3
#
#    percent_agree  match
# 0              1      1
#
# Finally, in non-small cell lung cancer ([[NSCLC]]) in patients' progressing on chemotherapy [[sutent]] was able to achieve a 10% response rate, a level of activity similar to those documented by other agents approved for lung cancer.
#
# ============================================================
# Unit id: 706124763
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_179  positive_speculative       2.397          3
#
#    percent_agree  match
# 0              1      1
#
# [[Sutent]] was also effective as second line treatment in patients with gastrointestinal stromal tumors ([[GIST]]) with 8% response rate, 70% stable disease and a 20-month median survival.
#
# ============================================================
# Unit id: 706124737
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_180  positive_speculative       2.397          3
#
#    percent_agree  match
# 0              1      1
#
# In addition, a phase II study in multitreated women with [[breast cancer]], [[sutent]] demonstrated a moderate activity with 16% clinical benefit.
#
# ============================================================
# Unit id: 706124739
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_181  positive_speculative      2.6039          3
#
#    percent_agree  match
# 0              1      1
#
# [[Epoetin beta]] effectively increases hemoglobin levels, reduces the need for transfusions and improves the quality of life in patients with symptomatic chemotherapy-induced [[anemia]] with a range of solid tumors and lymphoid malignancies.
#
# ============================================================
# Unit id: 706124761
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_184  positive_speculative       2.397          3
#
#    percent_agree  match
# 0              1      1
#
# During the induction phase, tacrolimus or cyclosporine, [[mycophenolate mofetil]], and methylprednisolone were used for [[immunosuppression]].
#
# ============================================================
# Unit id: 706124907
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_185  positive_speculative       2.609          3
#
#    percent_agree  match
# 0              1      1
#
# During the induction phase, [[tacrolimus]] or cyclosporine, mycophenolate mofetil, and methylprednisolone were used for [[immunosuppression]].
#
# ============================================================
# Unit id: 706124902
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_186  positive_speculative      2.5879          3
#
#    percent_agree  match
# 0              1      1
#
# During the induction phase, tacrolimus or cyclosporine, mycophenolate mofetil, and [[methylprednisolone]] were used for [[immunosuppression]].
#
# ============================================================
# Unit id: 706124758
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_187  positive_speculative      2.7424          3
#
#    percent_agree  match
# 0              1      1
#
# During the induction phase, tacrolimus or [[cyclosporine]], mycophenolate mofetil, and methylprednisolone were used for [[immunosuppression]].
#
# ============================================================
# Unit id: 706124797
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_188  positive_speculative      2.5598          3
#
#    percent_agree  match
# 0              1      1
#
# The most frequent and the most troublesome adverse effect of [[interferon]] plus ribavirin-based therapy is [[anaemia]].
#
# ============================================================
# Unit id: 706124709
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_189  positive_speculative      2.4892          3
#
#    percent_agree  match
# 0              1      1
#
# In multivariate analysis the risk of [[anaemia]] was significantly associated with [[zidovudine]] (OR, 3.27 95% CI, 1.64-6.54, P = 0.0008) and peg-IFN (OR, 2.35; 95% CI, 1.16-4.57, P = 0.0179).
#
# ============================================================
# Unit id: 707284912
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_19  positive_speculative      2.4833          3
#
#    percent_agree  match
# 0              1      1
#
# The results from these studies, encompassing end points measuring lung function and symptoms, found that [[montelukast]] provided effective and beneficial [[asthma]] control to children aged 2 to 14 years with mild asthma.
#
# ============================================================
# Unit id: 706124680
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_190  positive_speculative      6.2663          7
#
#    percent_agree  match
# 0              1      1
#
# [[Zidovudine]] discontinuation could help to avoid [[anaemia]] associated with anti-HCV therapy.
#
# ============================================================
# Unit id: 706124742
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_191  positive_speculative      3.3201          4
#
#    percent_agree  match
# 0              1      1
# The risk of [[anaemia]] was lower in patients with higher baseline haemoglobin levels (OR, 0.35 95% CI, 0.26-0.49, P < 0.0001) and in patients receiving [[protease inhibitor]]-based antiretroviral therapy (OR, 0.51 95% CI, 0.30-0.86, P = 0.0114).
#
# ============================================================
# Unit id: 706124716
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_192  positive_speculative      2.4221          3
#
#    percent_agree  match
# 0              1      1
#
# The most frequent and the most troublesome adverse effect of interferon plus [[ribavirin]]-based therapy is [[anaemia]].
#
# ============================================================
# Unit id: 706124732
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_193  positive_speculative      2.4004          3
#
#    percent_agree  match
# 0              1      1
#
# This study demonstrated that both low-dose topiramate and [[propranolol]] could significantly reduce [[migraine headache]] frequency, intensity, and duration.
#
# ============================================================
# Unit id: 707280277
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_194  positive_speculative      2.5879          3
#
#    percent_agree  match
# 0              1      1
#
# This study demonstrated that both low-dose [[topiramate]] and propranolol could significantly reduce [[migraine headache]] frequency, intensity, and duration.
#
# ============================================================
# Unit id: 706124825
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_197  positive_speculative      2.5666          3
#
#    percent_agree  match
# 0              1      1
#
# Long-term exposure to [[medium-dose glucocorticoid]] therapy associates with [[hypertension]] in patients with rheumatoid arthritis.
#
# ============================================================
# Unit id: 706124883
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_20  positive_speculative      2.6092          3
#
#    percent_agree  match
# 0              1      1
#
# This article reviewed recent results from randomized, double-blind studies of children with mild asthma treated with [[montelukast]], a leukotriene receptor antagonist that is approved for the treatment of asthma and [[allergic rhinitis]] in children and adults.
#
# ============================================================
# Unit id: 706124796
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_201  positive_speculative      3.2931          4
#
#    percent_agree  match
# 0              1      1
#
# Collectively, the cardiovascular benefit, metabolic neutrality and homogeneous blood pressure response illuminated in recent studies, and reviewed here, represent a reaffirmation of the benefit of [[long-acting dihydropyridine calcium channel antagonists]] and should serve to help reinforce the critical importance of these agents in the therapeutic armamentarium against [[cardiovascular disease]].
#
# ============================================================
# Unit id: 706124844
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_204  positive_speculative      3.4821          4
#
#    percent_agree  match
# 0              1      1
#
# Compared with both diuretics and contemporary agents, [[amlodipine]] decreases [[cardiovascular events]] to a similar or greater extent without evidence for increased coronary heart disease, gastrointestinal bleeding or cancer.
#
# ============================================================
# Unit id: 706124678
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_206  positive_speculative      4.1178          5
#
#    percent_agree  match
# 0              1      1
# All three patients had recurrent admissions for stomal bleeding and [[stomal varices secondary to portal hypertension]] and were initially treated with local measures (pressure, [[silver nitrate]], and suture ligation).
#
# ============================================================
# Unit id: 706124774
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_207  positive_speculative      2.4867          3
#
#    percent_agree  match
# 0              1      1
#
# All three patients had recurrent admissions for [[stomal bleeding]] and stomal varices secondary to portal hypertension and were initially treated with local measures (pressure, [[silver nitrate]], and suture ligation).
#
# ============================================================
# Unit id: 706124863
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_209  positive_speculative      2.5879          3
#
#    percent_agree  match
# 0              1      1
#
# At all doses studied, febuxostat more effectively lowered and maintained serum urate levels <6.0 mg/dl than did [[allopurinol]] (300 or 100 mg) or placebo in subjects with [[hyperuricemia]] and gout, including those with mild to moderately impaired renal function.
#
# ============================================================
# Unit id: 706124811
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_21  positive_speculative      2.3788          3
#
#    percent_agree  match
# 0              1      1
#
# The combination of high-dose MTX with [[procarbazine]] and CCNU is feasible and effective and results in a low rate of [[leukoencephalopathy]].
#
# ============================================================
# Unit id: 706124748
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_210  positive_speculative      2.5845          3
#
#    percent_agree  match
# 0              1      1
#
# A significantly (P < 0.05) higher percentage of subjects with [[impaired renal function]] treated with [[febuxostat]] 80 mg (4 [44%] of 9), 120 mg (5 [45%] of 11), and 240 mg (3 [60%] of 5) achieved the primary end point compared with those treated with 100 mg of allopurinol (0 [0%] of 10).
#
# ============================================================
# Unit id: 706124831
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_211  positive_speculative      3.3181          4
#
#    percent_agree  match
# 0              1      1
#
# The primary reasons for withdrawal were similar across groups except for [[gout flares]], which were more frequent with febuxostat than with [[allopurinol]].
#
# ============================================================
# Unit id: 706124730
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_212  positive_speculative      2.4221          3
#
#    percent_agree  match
# 0              1      1
#
# At all doses studied, [[febuxostat]] more effectively lowered and maintained serum urate levels <6.0 mg/dl than did allopurinol (300 or 100 mg) or placebo in subjects with hyperuricemia and [[gout]], including those with mild to moderately impaired renal function.
#
# ============================================================
# Unit id: 706124856
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_213  positive_speculative      2.4148          3
#
#    percent_agree  match
# 0              1      1
#
# At all doses studied, [[febuxostat]] more effectively lowered and maintained serum urate levels <6.0 mg/dl than did allopurinol (300 or 100 mg) or placebo in subjects with hyperuricemia and gout, including those with mild to moderately [[impaired renal function]].
#
# ============================================================
# Unit id: 706124789
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_214  positive_speculative      2.5598          3
#
#    percent_agree  match
# 0              1      1
# At all doses studied, [[febuxostat]] more effectively lowered and maintained serum urate levels <6.0 mg/dl than did allopurinol (300 or 100 mg) or placebo in subjects with [[hyperuricemia]] and gout, including those with mild to moderately impaired renal function.
#
# ============================================================
# Unit id: 706124815
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_216  positive_speculative      2.5078          3
#
#    percent_agree  match
# 0              1      1
#
# The primary reasons for withdrawal were similar across groups except for [[gout flares]], which were more frequent with [[febuxostat]] than with allopurinol.
#
# ============================================================
# Unit id: 706124906
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_217  positive_speculative      2.4833          3
#
#    percent_agree  match
# 0              1      1
#
# Proportions of subjects experiencing any adverse event or serious adverse event were similar across groups, although diarrhea and [[dizziness]] were more frequent in the [[febuxostat]] 240 mg group.
#
# ============================================================
# Unit id: 706124814
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_218  positive_speculative      2.5078          3
#
#    percent_agree  match
# 0              1      1
#
# Proportions of subjects experiencing any adverse event or serious adverse event were similar across groups, although [[diarrhea]] and dizziness were more frequent in the [[febuxostat]] 240 mg group.
#
# ============================================================
# Unit id: 706694486
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_22  positive_speculative      2.4148          3
#
#    percent_agree  match
# 0              1      1
#
# The combination of [[high-dose MTX]] with procarbazine and CCNU is feasible and effective and results in a low rate of [[leukoencephalopathy]].
#
# ============================================================
# Unit id: 706124728
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_220  positive_speculative      2.4221          3
#
#    percent_agree  match
# 0              1      1
#
# While the association between [[neural tube defects]] and [[antiepileptic drugs]] is well recognised, other congenital malformations are known to occur.
#
# ============================================================
# Unit id: 706124871
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_224  positive_speculative        2.85          3
#
#    percent_agree  match
# 0              1      1
#
# The patient was on corticosteroids and [[azathioprine]] for [[autoimmune hepatitis]] at the time of her presentation.
#
# ============================================================
# Unit id: 706124734
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_225  positive_speculative      2.5589          3
#
#    percent_agree  match
# 0              1      1
#
# [[Pulmonary alveolar proteinosis]]: a rare pulmonary toxicity of [[sirolimus]].
#
# ============================================================
# Unit id: 707276727
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_226  positive_speculative      2.4148          3
#
#    percent_agree  match
# 0              1      1
#
# [[PAP]] is a very rare complication of [[SRL]] therapy with only a few cases described.
#
# ============================================================
# Unit id: 706124837
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_23  positive_speculative      2.3778          3
#
#    percent_agree  match
# 0              1      1
#
# The combination of high-dose MTX with procarbazine and [[CCNU]] is feasible and effective and results in a low rate of [[leukoencephalopathy]].
#
# ============================================================
# Unit id: 707283394
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_230  positive_speculative      2.4148          3
#
#    percent_agree  match
# 0              1      1
#
# All patients converted to SRL because of [[GI side effects]] of [[MMF]] showed improvements, and none of those converted because of hyperglycemia experienced improvement.
#
# ============================================================
# Unit id: 706124879
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_231  positive_speculative      2.4833          3
#
#    percent_agree  match
# 0              1      1
#
# We concluded that conversion to SRL in pancreas transplantation should be considered an important alternative strategy, particularly for CNI nephrotoxicity and neurotoxicity, and in cases of [[severe diarrhea]] due to [[MMF]].
#
# ============================================================
# Unit id: 706124779
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_236  positive_speculative      2.5598          3
#
#    percent_agree  match
# 0              1      1
#
# Our data showed that [[oxcarbazepine]] can be a good alternative to traditional antiepileptic agents in the prevention of [[perioperative seizures]] being efficacy, ease of use (rapid titration in 3 days, not requiring close plasma concentration monitoring) and good tolerability (no major side effects during titration and during the first postoperative week) the key factors.
#
# ============================================================
# Unit id: 706124784
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_238  positive_speculative      2.4745          3
#
#    percent_agree  match
# 0              1      1
#
# We tested the hypothesis that [[oral beclomethasone dipropionate]] (BDP) would control gastrointestinal graft-versus-host disease ([[GVHD]]) in patients with anorexia, vomiting, and diarrhea.
#
# ============================================================
# Unit id: 706124895
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 0  drug_disease_240  positive_speculative       2.609          3
#
#    percent_agree  match
# 0              1      1
#
# Oral BDP prevents [[relapses of gastrointestinal GVHD]] following tapering of [[prednisone]]; survival is statistically significantly better among patients receiving BDP.
#
# ============================================================
# Unit id: 706124840
#
# ...
#
#    percent_agree  match
# 1       0.764019      1
# 0       0.235981      0
#
# [[Posaconazole]], in doses of 200 mg 3 times daily, reduced breakthrough [[invasive fungal infections]] (OR 0.30; 95% CI 0.12 to 0.71) and aspergillosis incidence (OR 0.31; 95% CI 0.13 to 0.75) in patients receiving hematopoietic stem-cell transplants compared with those receiving fluconazole.
#
# ============================================================
# Unit id: 706124804
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_24  positive_speculative      2.5901          3
# 0  drug_disease_24                 false      0.8000          1
#
#    percent_agree  match
# 1       0.764019      1
# 0       0.235981      0
#
# [[Intra-articular injection of lidocaine]] before closed reduction of [[anterior shoulder dislocation]] produces the same pain relief as intravenous meperidine and diazepam.
#
# ============================================================
# Unit id: 706124916
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_195  positive_speculative      2.5483          3
# 0  drug_disease_195                 false      0.8077          1
#
#    percent_agree  match
# 1       0.759327      1
# 0       0.240673      0
#
# Results - The [[topiramate]] group showed a reduction in the mean (+/-SD) of monthly migraine frequency from 6.07 (+/-1.89) to 1.83 (+/-1.39) episodes per month, [[headache]] intensity from 7.1 (+/-1.45) to 3.67 (+/-2.1) based on the Visual Analog Scale, and headache duration from 16.37 (+/-7.26) to 6.23 (+/-5.22) hours (P < 0.001).
#
# ============================================================
# Unit id: 706124757
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_164  positive_speculative      2.5971          3
# 0  drug_disease_164                 false      0.8333          1
#
#    percent_agree  match
# 1       0.757084      1
# 0       0.242916      0
#
# There was an estimated 50% excess risk of malignancy among [[methotrexate]]-exposed RA patients relative to the general population (SIR 1.5, 95% confidence interval [95% CI] 1.2-1.9), with a 3-fold increase in melanoma (SIR 3.0, 95% CI 1.2-6.2), a 5-fold increase in non-Hodgkin's lymphoma (SIR 5.1, 95% CI 2.2-10.0), and an almost 3-fold increase in [[lung cancer]] (SIR 2.9, 95% CI 1.6-4.8).
#
# ============================================================
# Unit id: 706124726
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_29  positive_speculative      2.5971          3
# 0  drug_disease_29                 false      0.8333          1
#
#    percent_agree  match
# 1       0.757084      1
# 0       0.242916      0
#
# Mean [[pain]] (mm) recorded before injection, before reduction, and after reduction in the [[intra-articular lidocaine]] group was 84.3 (95% confidence interval (CI) 79.8 to 88.8), 52.6 (95% CI 45.2 to 60.1), and 27.3 (95% CI 19.9 to 34.7), respectively.
#
# ============================================================
# Unit id: 707780960
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_234  positive_speculative      2.8611          3
# 0  drug_disease_234              negative      0.9333          1
#
#    percent_agree  match
# 1       0.754032      1
# 0       0.245968      0
#
# Moreover, [[oxcarbazepine]] can be a valid choice when long-term therapy is required because of the low interaction with other drugs and the low [[hematological side effects]].
#
# ============================================================
# Unit id: 706985414
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_105  positive_speculative      2.4421          3
# 0  drug_disease_105              negative      0.8333          1
#
#    percent_agree  match
# 1       0.745588      1
# 0       0.254412      0
#
# The most common adverse effects associated with the use of [[posaconazole]] include [[headache]], fever, nausea, vomiting, and diarrhea.
#
# ============================================================
# Unit id: 706124848
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 2  drug_disease_103  positive_speculative      4.3053          5
# 0  drug_disease_103                 false      0.8462          1
# 1  drug_disease_103              negative      0.7333          1
#
#    percent_agree  match
# 2       0.731597      1
# 0       0.143794      0
# 1       0.124609      0
#
# Similarly, the same regimen of [[posaconazole]] reduced invasive fungal infections (95% CI -9.7 to -2.5) and [[aspergillosis]] (CI not reported, p < 0.001) when compared with fluconazole and itraconazole in neutropenic patients.
#
# ============================================================
# Unit id: 706124846
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_26  positive_speculative      1.7594          2
# 0  drug_disease_26                 false      0.7273          1
#
#    percent_agree  match
# 1       0.707524      1
# 0       0.292476      0
#
# Intra-articular injection of lidocaine before closed reduction of anterior shoulder dislocation produces the same [[pain]] relief as intravenous meperidine and [[diazepam]].
#
# ============================================================
# Unit id: 706124710
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_196  positive_speculative      1.8517          2
# 0  drug_disease_196              negative      0.7692          1
#
#    percent_agree  match
# 1       0.706513      1
# 0       0.293487      0
#
# Results - The [[topiramate]] group showed a reduction in the mean (+/-SD) of monthly [[migraine]] frequency from 6.07 (+/-1.89) to 1.83 (+/-1.39) episodes per month, headache intensity from 7.1 (+/-1.45) to 3.67 (+/-2.1) based on the Visual Analog Scale, and headache duration from 16.37 (+/-7.26) to 6.23 (+/-5.22) hours (P < 0.001).
#
# ============================================================
# Unit id: 706124756
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_11  positive_speculative      1.9091          2
# 0  drug_disease_11              negative      0.8333          1
#
#    percent_agree  match
# 1       0.696142      1
# 0       0.303858      0
# ET-1 mRNA expression was significantly higher in patients with [[CsA]]-induced [[gingival overgrowth]] (P <0.001) than in patients with periodontitis and the controls.
#
# ============================================================
# Unit id: 706124723
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 2  drug_disease_215  positive_speculative      5.2462          6
# 1  drug_disease_215              negative      1.5549          2
# 0  drug_disease_215                 false      0.8000          1
#
#    percent_agree  match
# 2       0.690190      1
# 1       0.204562      0
# 0       0.105248      0
#
# A significantly (P < 0.05) higher percentage of subjects with [[impaired renal function]] treated with febuxostat 80 mg (4 [44%] of 9), 120 mg (5 [45%] of 11), and 240 mg (3 [60%] of 5) achieved the primary end point compared with those treated with 100 mg of [[allopurinol]] (0 [0%] of 10).
#
# ============================================================
# Unit id: 706124686
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 2  drug_disease_108  positive_speculative      5.3364          6
# 0  drug_disease_108                 false      1.7091          2
# 1  drug_disease_108              negative      0.7692          1
#
#    percent_agree  match
# 2       0.682867      1
# 0       0.218703      0
# 1       0.098430      0
#
# Similarly, the same regimen of posaconazole reduced [[invasive fungal infections]] (95% CI -9.7 to -2.5) and aspergillosis (CI not reported, p < 0.001) when compared with [[fluconazole]] and itraconazole in neutropenic patients.
#
# ============================================================
# Unit id: 706124855
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 2  drug_disease_208  positive_speculative      4.9656          6
# 0  drug_disease_208                 false      1.6333          2
# 1  drug_disease_208              negative      0.7333          1
#
#    percent_agree  match
# 2       0.677232      1
# 0       0.222757      0
# 1       0.100011      0
#
# At all doses studied, febuxostat more effectively lowered and maintained serum urate levels <6.0 mg/dl than did [[allopurinol]] (300 or 100 mg) or placebo in subjects with hyperuricemia and [[gout]], including those with mild to moderately impaired renal function.
#
# ============================================================
# Unit id: 706124744
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 2  drug_disease_148  positive_speculative      5.2119          6
# 0  drug_disease_148                 false      1.7564          2
# 1  drug_disease_148              negative      0.7692          1
#
#    percent_agree  match
# 2       0.673590      1
# 0       0.226998      0
# 1       0.099412      0
#
# Forty-one patients [30 males and 11 females, median age 47 years] consecutively diagnosed with [[PTCL]] received three courses of high-dose cyclophosphamide 2000 mg/m(2)/day, adriamycin 90 mg/m(2)/day, [[vincristine]] and prednisone alternating with three courses of etoposide, cisplatin, cytarabine and prednisone.
#
# ============================================================
# Unit id: 706124681
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 2  drug_disease_99  positive_speculative      4.4928          5
# 0  drug_disease_99                 false      1.6278          2
# 1  drug_disease_99              negative      1.5025          2
#
#    percent_agree  match
# 2       0.589367      1
# 0       0.213535      0
# 1       0.197098      0
#
# Similarly, the same regimen of posaconazole reduced invasive fungal infections (95% CI -9.7 to -2.5) and [[aspergillosis]] (CI not reported, p < 0.001) when compared with fluconazole and [[itraconazole]] in neutropenic patients.
#
# ============================================================
# Unit id: 706124841
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_62  positive_speculative      4.3012          5
# 0  drug_disease_62                 false      3.1240          4
#
#    percent_agree  match
# 1       0.579271      1
# 0       0.420729      0
#
# Calculated detectable differences for mortality/[[fatal malignancy]] with respect to the general population are 22%/49% for antimetabolites, 28%/62% for T-cell inhibitors, and 36%/81% for [[alkylating agents]].
#
# ============================================================
# Unit id: 706124805
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 2  drug_disease_100  positive_speculative      4.3753          5
# 0  drug_disease_100                 false      1.7333          2
# 1  drug_disease_100              negative      1.5025          2
#
#    percent_agree  match
# 2       0.574858      1
# 0       0.227733      0
# 1       0.197409      0
# Similarly, the same regimen of posaconazole reduced [[invasive fungal infections]] (95% CI -9.7 to -2.5) and aspergillosis (CI not reported, p < 0.001) when compared with fluconazole and [[itraconazole]] in neutropenic patients.
#
# ============================================================
# Unit id: 706124679
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 1  drug_disease_114  positive_speculative      4.6257          5
# 0  drug_disease_114                 false      3.4956          4
#
#    percent_agree  match
# 1       0.569576      1
# 0       0.430424      0
#
# Posaconazole, in doses of 200 mg 3 times daily, reduced breakthrough invasive fungal infections (OR 0.30; 95% CI 0.12 to 0.71) and [[aspergillosis]] incidence (OR 0.31; 95% CI 0.13 to 0.75) in patients receiving hematopoietic stem-cell transplants compared with those receiving [[fluconazole]].
#
# ============================================================
# Unit id: 706124771
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 2  drug_disease_39  positive_speculative      4.1544          5
# 1  drug_disease_39              negative      2.5743          3
# 0  drug_disease_39                 false      0.7333          1
#
#    percent_agree  match
# 2       0.556741      1
# 1       0.344988      0
# 0       0.098271      0
#
# Another important finding was that the cytotoxic effect induced by 25 microM or 50 microM of indomethacin-loaded nanocapsules or [[indomethacin ethyl ester-loaded nanocapsules]], in [[glioma]] cells was not observed in the organotypic cultures, indicating selective cytotoxicity of those formulations for tumoral cells.
#
# ============================================================
# Unit id: 706124684
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 2  drug_disease_65  positive_speculative      4.2677          5
# 1  drug_disease_65              negative      2.5999          3
# 0  drug_disease_65                 false      0.8000          1
#
#    percent_agree  match
# 2       0.556589      1
# 1       0.339076      0
# 0       0.104335      0
#
# There is evidence in the literature that [[inhaled corticosteroids]] (ICSs) are safe for pregnant women with [[asthma]] and their infants.
#
# ============================================================
# Unit id: 706124782
#
# EU-ADR answer: positive_speculative
# Experts agree: 3/3
#
#         pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 2  drug_disease_64  positive_speculative      4.1098          5
# 0  drug_disease_64                 false      2.4619          3
# 1  drug_disease_64              negative      0.8125          1
#
#    percent_agree  match
# 2       0.556567      1
# 0       0.333401      0
# 1       0.110032      0
#
# There is evidence in the literature that inhaled corticosteroids ([[ICSs]]) are safe for pregnant women with [[asthma]] and their infants.
#
# ============================================================
# Unit id: 706124712
#
# EU-ADR answer: positive_speculative
# Experts agree: 2/3
#
#          pub_rel_id        broad_rel_type  conf_score  num_votes  \
# 2  drug_disease_223  positive_speculative      3.3201          4
# 0  drug_disease_223                 false      3.2879          4
# 1  drug_disease_223              negative      0.7333          1
#
#    percent_agree  match
# 2       0.452250      1
# 0       0.447863      0
# 1       0.099887      0
#
# Data of our study revealed an unexpected high rate of hypogonadism irrespective of [[cyclophosphamide]] use, and subclinical involvement of the testes by the [[vasculitis]] itself might be an alternative explanation.
#
# ============================================================

# %%
def graph_confidence(work_units):
    conf = []
    
    for rel_id in work_units:
        group = results.query("pub_rel_id == '{0}'".format(rel_id))
        
        conf.append(group.iloc[0]["percent_agree"])
        
    graph = pd.Series(sorted(conf, reverse = True)).plot()
    
    graph.set_ylim((0, 1.1))

# %%
graph_confidence(matches)

# %%
graph_confidence(mismatches)

# %%
graph_confidence(matches + mismatches)
