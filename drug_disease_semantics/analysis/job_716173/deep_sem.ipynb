# %% [markdown]
# ## Deep semantic choices for job 716173 with the 4 relation types

# %% [markdown]
# 2015-04-22 Tong Shu Li

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from itertools import islice
from collections import Counter

# %%
import sys
sys.path.append("/home/toby/crowdsourcing/drug_disease_semantics/src/")

from filter_data import filter_data
from true_relation_type import get_euadr_relation_type
from aggregate_results import aggregate_results
from aggregate_votes import aggregate_votes
from get_orig_problem import get_orig_problem

# %%
sys.path.append("/home/toby/global_util/")
from file_util import read_file

# %% [markdown]
# Read our data:

# %%
settings = {
    "loc": "/home/toby/crowdsourcing/drug_disease_semantics/data/",
    "fname": "job_716713_full_with_untrusted_and_unfinished.tsv",
    "data_subset": "normal",
    "min_accuracy": 0.7,
    "max_accuracy": 1.0,
    "id_column": "pub_rel_id"
}

# %%
raw_data = filter_data(settings)

# %%
euadr_answer = get_euadr_relation_type(settings)

# %%
len(raw_data)
# Out:
# 1022

# %%
def create_match(gold_std_answer):
    def match(identifier, crowd_choice):
        return int(crowd_choice == gold_std_answer[identifier])
    
    return match

# %%
match_obj = create_match(euadr_answer)

# %%
results = aggregate_results("pub_rel_id", "broad_rel_type", raw_data, match_obj)

# %% [markdown]
# Look at the results:

# %%
def determine_matches(results):
    matches = []
    mismatches = []
    for rel_id, group in results.groupby("pub_rel_id"):
        if group.iloc[0]["match"] == 1:
            matches.append(rel_id)
        else:
            mismatches.append(rel_id)
            
    return (matches, mismatches)

# %%
matches, mismatches = determine_matches(results)

# %%
len(matches)
# Out:
# 165

# %%
len(mismatches)
# Out:
# 79

# %%
def deep_sem_summary(work_units):
    temp = []
    for rel_id in work_units:
        subset = results.query("pub_rel_id == '{0}'".format(rel_id))
        top_choice = subset.iloc[0]["broad_rel_type"]
        
        if top_choice in ["positive", "speculative"]:
            raw_subset = raw_data.query("pub_rel_id == '{0}'".format(rel_id))

            top_subset = raw_subset.query("broad_rel_type == '{0}'".format(top_choice))

            ans = aggregate_votes("deep_semantics", top_subset)
            
            total_vote_score = sum(ans["conf_score"])
            percent_agree = ans["conf_score"] / total_vote_score
            
            ans["percent_agree"] = percent_agree
            ans.insert(0, "pub_rel_id", rel_id)
            
            ans = ans.sort(["conf_score"], ascending = False)
            
            temp.append(ans)
            
    return pd.concat(temp)

# %%
deep_sem_res = deep_sem_summary(matches)

# %%
loc = "/home/toby/crowdsourcing/drug_disease_semantics/data/"

pub_to_raw_mapping = dict()
for line in islice(read_file(loc + "raw_to_toby_mapping.txt"), 1, None):
    pub_rel_id, raw_rel_id, num_agree = line.split('|')
    pub_to_raw_mapping[pub_rel_id] = (raw_rel_id, int(num_agree))

# %%
orig_problem = get_orig_problem("pub_rel_id", raw_data)

# %%
def summary(work_units):
    for identifier in work_units:
        subset = results.query("pub_rel_id == '{0}'".format(identifier))
        
        unit_id = raw_data.query("pub_rel_id == '{0}'".format(identifier)).iloc[0]["_unit_id"]
        
        deep_subset = deep_sem_res.query("pub_rel_id == '{0}'".format(identifier))
        
        print "Unit id: {0}".format(unit_id)
        print
        print "EU-ADR answer:", euadr_answer[identifier]
        print "Experts agree: {0}/3".format(pub_to_raw_mapping[identifier][1])
        print
        print subset
        print
        if not deep_subset.empty:
            print deep_subset
            print
        print orig_problem[identifier][3]
        print
        print "============================================================"

# %%
summary(matches)
# Out:
# Unit id: 706124714
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#        pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_0       positive      2.5589          3              1      1
#
#        pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_0      may_cause      2.5589          3              1
#
# Body height, weight and obesity increase the risk of [[venous thrombosis]], especially obesity in women using [[oral contraceptives]].
#
# ============================================================
# Unit id: 706124715
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_10          false      4.2055          5       0.845378      1
# 1  drug_disease_10       negative      0.7692          1       0.154622      0
#
# ET-1 mRNA expression was significantly higher in patients with [[CsA]]-induced gingival overgrowth (P <0.001) than in patients with [[periodontitis]] and the controls.
#
# ============================================================
# Unit id: 706124805
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 2  drug_disease_100       positive      4.3753          5       0.574858
# 0  drug_disease_100          false      1.7333          2       0.227733
# 1  drug_disease_100       negative      1.5025          2       0.197409
#
#    match
# 2      1
# 0      0
# 1      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_100  used_to_treat      4.3753          5              1
#
# Similarly, the same regimen of posaconazole reduced [[invasive fungal infections]] (95% CI -9.7 to -2.5) and aspergillosis (CI not reported, p < 0.001) when compared with fluconazole and [[itraconazole]] in neutropenic patients.
#
# ============================================================
# Unit id: 706124787
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_101       positive      2.3788          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_101      may_cause      2.3788          3              1
#
# The most common adverse effects associated with the use of [[posaconazole]] include headache, fever, [[nausea]], vomiting, and diarrhea.
#
# ============================================================
# Unit id: 706124869
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_102       positive      2.5879          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_102      may_cause      2.5879          3              1
#
# The most common adverse effects associated with the use of [[posaconazole]] include headache, fever, nausea, [[vomiting]], and diarrhea.
#
# ============================================================
# Unit id: 706124848
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 2  drug_disease_103       positive      4.3053          5       0.731597
# 0  drug_disease_103          false      0.8462          1       0.143794
# 1  drug_disease_103       negative      0.7333          1       0.124609
#
#    match
# 2      1
# 0      0
# 1      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_103  used_to_treat      4.3053          5              1
#
# Similarly, the same regimen of [[posaconazole]] reduced invasive fungal infections (95% CI -9.7 to -2.5) and [[aspergillosis]] (CI not reported, p < 0.001) when compared with fluconazole and itraconazole in neutropenic patients.
#
# ============================================================
# Unit id: 706124890
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_104       positive      2.6092          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_104  used_to_treat      2.6092          3              1
#
# Similarly, the same regimen of [[posaconazole]] reduced [[invasive fungal infections]] (95% CI -9.7 to -2.5) and aspergillosis (CI not reported, p < 0.001) when compared with fluconazole and itraconazole in neutropenic patients.
#
# ============================================================
# Unit id: 706985414
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 1  drug_disease_105       positive      2.4421          3       0.745588
# 0  drug_disease_105       negative      0.8333          1       0.254412
#
#    match
# 1      1
# 0      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_105      may_cause      2.4421          3              1
#
# The most common adverse effects associated with the use of [[posaconazole]] include [[headache]], fever, nausea, vomiting, and diarrhea.
#
# ============================================================
# Unit id: 706124686
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 2  drug_disease_108       positive      5.3364          6       0.682867
# 0  drug_disease_108          false      1.7091          2       0.218703
# 1  drug_disease_108       negative      0.7692          1       0.098430
#
#    match
# 2      1
# 0      0
# 1      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_108  used_to_treat      4.4133          5       0.827018
# 0  drug_disease_108      may_cause      0.9231          1       0.172982
#
# Similarly, the same regimen of posaconazole reduced [[invasive fungal infections]] (95% CI -9.7 to -2.5) and aspergillosis (CI not reported, p < 0.001) when compared with [[fluconazole]] and itraconazole in neutropenic patients.
#
# ============================================================
# Unit id: 706124756
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 1  drug_disease_11       positive      1.9091          2       0.696142      1
# 0  drug_disease_11       negative      0.8333          1       0.303858      0
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_11      may_cause      1.9091          2              1
# ET-1 mRNA expression was significantly higher in patients with [[CsA]]-induced [[gingival overgrowth]] (P <0.001) than in patients with periodontitis and the controls.
#
# ============================================================
# Unit id: 706124830
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_110       positive      2.3788          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_110  used_to_treat      1.6515          2       0.694258
# 0  drug_disease_110          other      0.7273          1       0.305742
#
# [[Posaconazole]], in doses of 200 mg 3 times daily, reduced breakthrough invasive fungal infections (OR 0.30; 95% CI 0.12 to 0.71) and [[aspergillosis]] incidence (OR 0.31; 95% CI 0.13 to 0.75) in patients receiving hematopoietic stem-cell transplants compared with those receiving fluconazole.
#
# ============================================================
# Unit id: 706124775
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 1  drug_disease_111       positive      2.5901          3       0.764019
# 0  drug_disease_111          false      0.8000          1       0.235981
#
#    match
# 1      1
# 0      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_111  used_to_treat      2.5901          3              1
#
# [[Posaconazole]], in doses of 200 mg 3 times daily, reduced breakthrough [[invasive fungal infections]] (OR 0.30; 95% CI 0.12 to 0.71) and aspergillosis incidence (OR 0.31; 95% CI 0.13 to 0.75) in patients receiving hematopoietic stem-cell transplants compared with those receiving fluconazole.
#
# ============================================================
# Unit id: 706124885
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_112       positive      2.5879          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_112  used_to_treat      2.5879          3              1
#
# Posaconazole is noninferior to [[fluconazole]] for treatment of [[oropharyngeal candidiasis]] (95% CI -6.6 to 5.0), but necessity for this indication remains unclear, as many other treatment options exist.
#
# ============================================================
# Unit id: 706124821
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_113       positive      2.4848          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_113  used_to_treat      1.6515          2       0.664641
# 0  drug_disease_113      may_cause      0.8333          1       0.335359
#
# Posaconazole, in doses of 200 mg 3 times daily, reduced breakthrough [[invasive fungal infections]] (OR 0.30; 95% CI 0.12 to 0.71) and aspergillosis incidence (OR 0.31; 95% CI 0.13 to 0.75) in patients receiving hematopoietic stem-cell transplants compared with those receiving [[fluconazole]].
#
# ============================================================
# Unit id: 706124679
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 1  drug_disease_114       positive      4.6257          5       0.569576
# 0  drug_disease_114          false      3.4956          4       0.430424
#
#    match
# 1      1
# 0      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_114  used_to_treat      3.7026          4       0.800441
# 0  drug_disease_114      may_cause      0.9231          1       0.199559
#
# Posaconazole, in doses of 200 mg 3 times daily, reduced breakthrough invasive fungal infections (OR 0.30; 95% CI 0.12 to 0.71) and [[aspergillosis]] incidence (OR 0.31; 95% CI 0.13 to 0.75) in patients receiving hematopoietic stem-cell transplants compared with those receiving [[fluconazole]].
#
# ============================================================
# Unit id: 706124917
#
# EU-ADR answer: speculative
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 1  drug_disease_115    speculative      4.8437          6       0.655733
# 0  drug_disease_115       positive      2.5430          3       0.344267
#
#    match
# 1      1
# 0      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_115  used_to_treat      2.5165          3       0.519541
# 0  drug_disease_115      may_cause      2.3272          3       0.480459
#
# While some beneficial neuromotor effects of succimer therapy were observed in the present study there remains several unanswered questions such as how long these effects will persist and how [[succimer]] therapy modifies lead-associated [[cerebellar deficits]] manifesting as perturbations in vestibular and/or proprioception systems for postural balance and functional locomotion.
#
# ============================================================
# Unit id: 706989513
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_117       positive      2.4451          3       0.740446
# 1  drug_disease_117    speculative      0.8571          1       0.259554
#
#    match
# 0      1
# 1      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_117      may_cause      2.4451          3              1
#
# It is well known that [[tobacco smoke]] exposure is related to the risk of developing [[cardiovascular diseases]] and events.
#
# ============================================================
# Unit id: 706124836
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_118       positive      2.4745          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_118  used_to_treat      2.4745          3              1
#
# [[Tibolone]] is a selective tissue estrogenic activity regulator, approved for the treatment of [[vasomotor symptoms]] in postmenopausal women.
#
# ============================================================
# Unit id: 706124687
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_12       positive      4.2616          5       0.840668      1
# 1  drug_disease_12    speculative      0.8077          1       0.159332      0
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_12      may_cause      4.2616          5              1
# These results suggest that CsA can modulate the expression of ET-1 in gingival fibroblasts and [[CsA]]-induced [[gingival overgrowth]].
#
# ============================================================
# Unit id: 706124702
#
# EU-ADR answer: negative
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_126       negative       2.397          3              1
#
#    match
# 0      1
#
# We found no evidence of impaired control of the carbohydrate and lipid metabolism or aggravation of [[vascular lesions]] during the two years an [[etonogestrel]] implant was used by diabetic women.
#
# ============================================================
# Unit id: 706124694
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_127       positive      5.1121          6       0.745802
# 1  drug_disease_127    speculative      1.7424          2       0.254198
#
#    match
# 0      1
# 1      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_127  used_to_treat      5.1121          6              1
#
# [[Oritavancin]]: a new promising agent in the treatment of [[infections due to Gram-positive pathogens]].
#
# ============================================================
# Unit id: 706124772
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_128       positive      2.4854          3        0.75473
# 1  drug_disease_128    speculative      0.8077          1        0.24527
#
#    match
# 0      1
# 1      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_128      may_cause      2.4854          3              1
#
# Our findings support that ecstasy use, or [[ecstasy/cannabis]] synergic effects, are responsible for the sub-clinical deficits observed in ecstasy polydrug users, and provides additional evidence for [[long-term cognitive impairment]] owing to ecstasy consumption in the context of polydrug use.
#
# ============================================================
# Unit id: 707282367
#
# EU-ADR answer: false
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_13          false      2.3596          3              1      1
#
# Gingival samples were collected from eight normal healthy individuals, eight patients with [[periodontitis]], and eight patients with cyclosporin A ([[CsA]])-induced gingival overgrowth.
#
# ============================================================
# Unit id: 706124785
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_136       positive      2.5078          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_136      may_cause      2.5078          3              1
#
# Adverse events were similar across treatment groups except for higher rates of [[anemia]] in the groups receiving [[ribavirin]].
#
# ============================================================
# Unit id: 706124764
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_137       positive      2.5078          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_137  used_to_treat      2.5078          3              1
#
# Sustained virologic response (SVR) rates of 50%-60% have been achieved in patients with [[chronic hepatitis C genotype 4]] treated with peginterferon plus [[ribavirin]].
#
# ============================================================
# Unit id: 706124877
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_139       positive      1.7500          2       0.704707
# 1  drug_disease_139    speculative      0.7333          1       0.295293
#
#    match
# 0      1
# 1      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_139      may_cause        1.75          2              1
#
# For exposure levels within standard recommended guidelines, [[radioisotopes]] are far more likely to play a role in the occurrence of [[spontaneous abortions]] than X-rays.
#
# ============================================================
# Unit id: 706124688
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_14       positive      2.4221          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_14      may_cause      2.4221          3              1
#
# Gingival samples were collected from eight normal healthy individuals, eight patients with periodontitis, and eight patients with [[cyclosporin A]] (CsA)-induced [[gingival overgrowth]].
#
# ============================================================
# Unit id: 706124719
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_141       positive      2.6754          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_141  used_to_treat      1.8421          2       0.688533
# 0  drug_disease_141      may_cause      0.8333          1       0.311467
#
# An open multicenter phase II trial of weekly [[docetaxel]] for [[advanced-stage non-small-cell lung cancer]] in elderly patients with significant comorbidity and/or poor performance status: The GFPC 02-02b study.
#
# ============================================================
# Unit id: 706124882
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_142       positive      2.4148          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_142      may_cause      2.4148          3              1
#
# Contrarily, [[LABA]] showed a significant increase in [[asthma-related deaths]] (Relative Risk=3.83; 95% CI, 1.21-12.14).
#
# ============================================================
# Unit id: 706124765
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_144       positive      2.4245          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_144  used_to_treat      2.4245          3              1
#
# Forty-one patients [30 males and 11 females, median age 47 years] consecutively diagnosed with [[PTCL]] received three courses of [[high-dose cyclophosphamide]] 2000 mg/m(2)/day, adriamycin 90 mg/m(2)/day, vincristine and prednisone alternating with three courses of etoposide, cisplatin, cytarabine and prednisone.
#
# ============================================================
# Unit id: 706124812
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_145       positive      2.5873          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_145  used_to_treat      1.7748          2       0.685966
# 0  drug_disease_145      may_cause      0.8125          1       0.314034
#
# Forty-one patients [30 males and 11 females, median age 47 years] consecutively diagnosed with [[PTCL]] received three courses of high-dose cyclophosphamide 2000 mg/m(2)/day, [[adriamycin]] 90 mg/m(2)/day, vincristine and prednisone alternating with three courses of etoposide, cisplatin, cytarabine and prednisone.
#
# ============================================================
# Unit id: 706124829
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_146       positive      2.5598          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_146  used_to_treat      2.5598          3              1
#
# Forty-one patients [30 males and 11 females, median age 47 years] consecutively diagnosed with [[PTCL]] received three courses of high-dose cyclophosphamide 2000 mg/m(2)/day, adriamycin 90 mg/m(2)/day, vincristine and prednisone alternating with three courses of etoposide, [[cisplatin]], cytarabine and prednisone.
#
# ============================================================
# Unit id: 706124820
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_147       positive      2.5873          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_147  used_to_treat      1.7748          2       0.685966
# 0  drug_disease_147      may_cause      0.8125          1       0.314034
#
# Forty-one patients [30 males and 11 females, median age 47 years] consecutively diagnosed with [[PTCL]] received three courses of high-dose cyclophosphamide 2000 mg/m(2)/day, adriamycin 90 mg/m(2)/day, vincristine and prednisone alternating with three courses of etoposide, cisplatin, cytarabine and [[prednisone]].
#
# ============================================================
# Unit id: 706124744
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 2  drug_disease_148       positive      3.4811          4       0.449900
# 0  drug_disease_148          false      1.7564          2       0.226998
# 3  drug_disease_148    speculative      1.7308          2       0.223690
# 1  drug_disease_148       negative      0.7692          1       0.099412
#
#    match
# 2      1
# 0      0
# 3      0
# 1      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_148  used_to_treat      3.4811          4              1
# Forty-one patients [30 males and 11 females, median age 47 years] consecutively diagnosed with [[PTCL]] received three courses of high-dose cyclophosphamide 2000 mg/m(2)/day, adriamycin 90 mg/m(2)/day, [[vincristine]] and prednisone alternating with three courses of etoposide, cisplatin, cytarabine and prednisone.
#
# ============================================================
# Unit id: 706124770
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 1  drug_disease_149       positive      4.1183          5       0.834255
# 0  drug_disease_149          false      0.8182          1       0.165745
#
#    match
# 1      1
# 0      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_149  used_to_treat      4.1183          5              1
#
# Forty-one patients [30 males and 11 females, median age 47 years] consecutively diagnosed with [[PTCL]] received three courses of high-dose cyclophosphamide 2000 mg/m(2)/day, adriamycin 90 mg/m(2)/day, vincristine and prednisone alternating with three courses of etoposide, cisplatin, [[cytarabine]] and prednisone.
#
# ============================================================
# Unit id: 706124768
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_15       positive      4.0652          5       0.719695      1
# 1  drug_disease_15    speculative      1.5833          2       0.280305      0
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_15  used_to_treat      4.0652          5              1
#
# The evidence suggests that [[montelukast]] is an effective monotherapy controller in children with [[mild asthma]].
#
# ============================================================
# Unit id: 707287260
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_150       positive        2.85          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_150  used_to_treat        2.85          3              1
#
# Forty-one patients [30 males and 11 females, median age 47 years] consecutively diagnosed with [[PTCL]] received three courses of high-dose cyclophosphamide 2000 mg/m(2)/day, adriamycin 90 mg/m(2)/day, vincristine and prednisone alternating with three courses of [[etoposide]], cisplatin, cytarabine and prednisone.
#
# ============================================================
# Unit id: 706124740
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_151       positive       2.397          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_151  used_to_treat      1.6278          2       0.679099
# 0  drug_disease_151      may_cause      0.7692          1       0.320901
#
# Plasma [[ziprasidone]] levels ranged from 20 ng/mL to 160 ng/mL (mean: 75.8 ng/mL) and were significantly related to the improvement in [[negative symptoms]].
#
# ============================================================
# Unit id: 706124683
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_153       positive      2.6322          3              1
#
#    match
# 0      1
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_153      may_cause      2.6322          3              1
#
# Characteristic features of an [[inflammation]] induced by [[bevacizumab]] injection include an early onset with painless loss in VA mostly without conjunctival or ciliary injection.
#
# ============================================================
# Unit id: 706124794
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_154       positive      2.4745          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_154  used_to_treat      1.6745          2       0.676702
# 0  drug_disease_154      may_cause      0.8000          1       0.323298
#
# Administration of full-dose R-CHOP (rituximab/cyclophosphamide/doxorubicin/vincristine/[[prednisone]]) chemotherapy is important to maximize response in patients with intermediate-or [[high-grade non-Hodgkin lymphoma]] but might be difficult in older patients.
#
# ============================================================
# Unit id: 706124919
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_155       positive      2.5879          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_155  used_to_treat      2.5879          3              1
#
# Administration of full-dose R-CHOP ([[rituximab]]/cyclophosphamide/doxorubicin/vincristine/prednisone) chemotherapy is important to maximize response in patients with intermediate-or [[high-grade non-Hodgkin lymphoma]] but might be difficult in older patients.
#
# ============================================================
# Unit id: 706124759
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_156       positive      2.6209          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_156  used_to_treat      2.6209          3              1
#
# Administration of full-dose R-CHOP (rituximab/cyclophosphamide/[[doxorubicin]]/vincristine/prednisone) chemotherapy is important to maximize response in patients with intermediate-or [[high-grade non-Hodgkin lymphoma]] but might be difficult in older patients.
#
# ============================================================
# Unit id: 706124776
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_157       positive      2.3778          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_157  used_to_treat      2.3778          3              1
#
# Administration of full-dose R-CHOP (rituximab/[[cyclophosphamide]]/doxorubicin/vincristine/prednisone) chemotherapy is important to maximize response in patients with intermediate-or [[high-grade non-Hodgkin lymphoma]] but might be difficult in older patients.
#
# ============================================================
# Unit id: 706124786
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_158       positive      2.6744          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_158  used_to_treat      2.6744          3              1
#
# Administration of full-dose R-CHOP (rituximab/cyclophosphamide/doxorubicin/[[vincristine]]/prednisone) chemotherapy is important to maximize response in patients with intermediate-or [[high-grade non-Hodgkin lymphoma]] but might be difficult in older patients.
#
# ============================================================
# Unit id: 706124858
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_159       positive      2.6092          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_159      may_cause      1.8015          2       0.690442
# 1  drug_disease_159  used_to_treat      0.8077          1       0.309558
#
# Compared with the general population, [[methotrexate]]-treated RA patients have an increased incidence of melanoma, non-Hodgkin's lymphoma, and [[lung cancer]].
#
# ============================================================
# Unit id: 706124881
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_160       positive      2.3596          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_160      may_cause      2.3596          3              1
#
# Compared with the general population, [[methotrexate]]-treated RA patients have an increased incidence of [[melanoma]], non-Hodgkin's lymphoma, and lung cancer.
#
# ============================================================
# Unit id: 707218352
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_161       positive      2.5421          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_161      may_cause      2.5421          3              1
#
# Compared with the general population, [[methotrexate]]-treated RA patients have an increased incidence of melanoma, [[non-Hodgkin's lymphoma]], and lung cancer.
#
# ============================================================
# Unit id: 706124795
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_163       positive      2.5873          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_163      may_cause      2.5873          3              1
#
# There was an estimated 50% excess risk of malignancy among [[methotrexate]]-exposed RA patients relative to the general population (SIR 1.5, 95% confidence interval [95% CI] 1.2-1.9), with a 3-fold increase in melanoma (SIR 3.0, 95% CI 1.2-6.2), a 5-fold increase in [[non-Hodgkin's lymphoma]] (SIR 5.1, 95% CI 2.2-10.0), and an almost 3-fold increase in lung cancer (SIR 2.9, 95% CI 1.6-4.8).
#
# ============================================================
# Unit id: 706124757
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 1  drug_disease_164       positive      2.5971          3       0.757084
# 0  drug_disease_164          false      0.8333          1       0.242916
#
#    match
# 1      1
# 0      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_164      may_cause      2.5971          3              1
#
# There was an estimated 50% excess risk of malignancy among [[methotrexate]]-exposed RA patients relative to the general population (SIR 1.5, 95% confidence interval [95% CI] 1.2-1.9), with a 3-fold increase in melanoma (SIR 3.0, 95% CI 1.2-6.2), a 5-fold increase in non-Hodgkin's lymphoma (SIR 5.1, 95% CI 2.2-10.0), and an almost 3-fold increase in [[lung cancer]] (SIR 2.9, 95% CI 1.6-4.8).
#
# ============================================================
# Unit id: 706124835
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_165       positive      2.5078          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_165      may_cause      2.5078          3              1
#
# There was an estimated 50% excess risk of malignancy among [[methotrexate]]-exposed RA patients relative to the general population (SIR 1.5, 95% confidence interval [95% CI] 1.2-1.9), with a 3-fold increase in [[melanoma]] (SIR 3.0, 95% CI 1.2-6.2), a 5-fold increase in non-Hodgkin's lymphoma (SIR 5.1, 95% CI 2.2-10.0), and an almost 3-fold increase in lung cancer (SIR 2.9, 95% CI 1.6-4.8).
#
# ============================================================
# Unit id: 706124852
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_166       positive      2.5598          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_166  used_to_treat      2.5598          3              1
#
# Incidence of melanoma and other malignancies among [[rheumatoid arthritis]] patients treated with [[methotrexate]].
#
# ============================================================
# Unit id: 706124894
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_167       positive      2.6836          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_167  used_to_treat      1.8503          2       0.689484
# 0  drug_disease_167      may_cause      0.8333          1       0.310516
#
# To determine cancer risk in a cohort of 459 [[rheumatoid arthritis]] (RA) patients treated with [[methotrexate]] in community practice.
#
# ============================================================
# Unit id: 706124912
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_168       positive      1.6648          2       0.689415
# 1  drug_disease_168    speculative      0.7500          1       0.310585
#
#    match
# 0      1
# 1      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_168  used_to_treat      0.8571          1       0.514837
# 0  drug_disease_168      may_cause      0.8077          1       0.485163
#
# To determine [[cancer]] risk in a cohort of 459 rheumatoid arthritis (RA) patients treated with [[methotrexate]] in community practice.
#
# ============================================================
# Unit id: 706124828
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_169       positive      2.5666          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_169      may_cause      1.7666          2       0.688304
# 1  drug_disease_169  used_to_treat      0.8000          1       0.311696
#
# Incidence of melanoma and other [[malignancies]] among rheumatoid arthritis patients treated with [[methotrexate]].
#
# ============================================================
# Unit id: 706124721
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_170       positive      2.4892          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_170      may_cause      1.6559          2       0.665234
# 1  drug_disease_170  used_to_treat      0.8333          1       0.334766
#
# Incidence of [[melanoma]] and other malignancies among rheumatoid arthritis patients treated with [[methotrexate]].
#
# ============================================================
# Unit id: 706124803
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_172       positive      2.5666          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_172      may_cause      2.5666          3              1
#
# Absence of villin predisposes mice to [[dextran sodium sulfate]]-induced [[colitis]] by promoting apoptosis.
#
# ============================================================
# Unit id: 706124816
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 1  drug_disease_175       positive      3.3668          4       0.808006
# 0  drug_disease_175          false      0.8000          1       0.191994
#
#    match
# 1      1
# 0      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_175      may_cause      3.3668          4              1
#
# Dental surgery for these children has historically consisted of decreasing and/or discontinuing the oral anticoagulant and instituting [[heparin]] therapy prior to the planned dental procedure, which can result in [[thromboembolism]] and increased morbidity and mortality.
#
# ============================================================
# Unit id: 706124727
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_176       positive      2.4221          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_176  used_to_treat      2.4221          3              1
#
# Finally, in non-small cell lung cancer (NSCLC) in patients' progressing on chemotherapy [[sutent]] was able to achieve a 10% response rate, a level of activity similar to those documented by other agents approved for [[lung cancer]].
#
# ============================================================
# Unit id: 706124793
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_177       positive      2.5078          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_177  used_to_treat      2.5078          3              1
#
# In several phase I/II/III studies, [[sutent]] was found to be effective as second and first line treatment in [[metastatic renal cell carcinoma]] (RCC).
#
# ============================================================
# Unit id: 706124911
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_178       positive      2.5879          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_178  used_to_treat      2.5879          3              1
#
# Finally, in non-small cell lung cancer ([[NSCLC]]) in patients' progressing on chemotherapy [[sutent]] was able to achieve a 10% response rate, a level of activity similar to those documented by other agents approved for lung cancer.
#
# ============================================================
# Unit id: 706124763
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_179       positive       2.397          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_179  used_to_treat       2.397          3              1
#
# [[Sutent]] was also effective as second line treatment in patients with gastrointestinal stromal tumors ([[GIST]]) with 8% response rate, 70% stable disease and a 20-month median survival.
#
# ============================================================
# Unit id: 706124737
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_180       positive       2.397          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_180  used_to_treat       2.397          3              1
#
# In addition, a phase II study in multitreated women with [[breast cancer]], [[sutent]] demonstrated a moderate activity with 16% clinical benefit.
#
# ============================================================
# Unit id: 706124739
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_181       positive      2.6039          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_181  used_to_treat      2.6039          3              1
#
# [[Epoetin beta]] effectively increases hemoglobin levels, reduces the need for transfusions and improves the quality of life in patients with symptomatic chemotherapy-induced [[anemia]] with a range of solid tumors and lymphoid malignancies.
#
# ============================================================
# Unit id: 706124761
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_184       positive       2.397          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_184  used_to_treat       2.397          3              1
#
# During the induction phase, tacrolimus or cyclosporine, [[mycophenolate mofetil]], and methylprednisolone were used for [[immunosuppression]].
#
# ============================================================
# Unit id: 706124907
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_185       positive       2.609          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_185  used_to_treat       2.609          3              1
#
# During the induction phase, [[tacrolimus]] or cyclosporine, mycophenolate mofetil, and methylprednisolone were used for [[immunosuppression]].
#
# ============================================================
# Unit id: 706124902
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_186       positive      2.5879          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_186  used_to_treat      2.5879          3              1
#
# During the induction phase, tacrolimus or cyclosporine, mycophenolate mofetil, and [[methylprednisolone]] were used for [[immunosuppression]].
#
# ============================================================
# Unit id: 706124758
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_187       positive      2.7424          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_187  used_to_treat      2.7424          3              1
#
# During the induction phase, tacrolimus or [[cyclosporine]], mycophenolate mofetil, and methylprednisolone were used for [[immunosuppression]].
#
# ============================================================
# Unit id: 706124797
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_188       positive      2.5598          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_188      may_cause      2.5598          3              1
#
# The most frequent and the most troublesome adverse effect of [[interferon]] plus ribavirin-based therapy is [[anaemia]].
#
# ============================================================
# Unit id: 706124709
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_189       positive      2.4892          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_189      may_cause      2.4892          3              1
#
# ...
# 0  drug_disease_65          false      0.8000          1       0.104335      0
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_65  used_to_treat      4.2677          5              1
#
# There is evidence in the literature that [[inhaled corticosteroids]] (ICSs) are safe for pregnant women with [[asthma]] and their infants.
#
# ============================================================
# Unit id: 707283605
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_69       positive       2.609          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_69  used_to_treat       2.609          3              1
#
# [[5-aminosalicylic acid]] inhibits [[colitis-associated colorectal dysplasias]] in the mouse model of azoxymethane/dextran sulfate sodium-induced colitis.
#
# ============================================================
# Unit id: 706124892
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#        pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_7       positive      2.6836          3              1      1
#
#        pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_7  used_to_treat      1.8503          2       0.689484
# 0  drug_disease_7      may_cause      0.8333          1       0.310516
#
# We describe the case of a 10-year-old boy who developed systemic weakness following treatment of [[spasticity]] with [[botulinum toxin type B]].
#
# ============================================================
# Unit id: 706124802
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_70       positive      2.4245          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_70      may_cause      2.4245          3              1
#
# The chemopreventive activity of 5-ASA was evaluated in the Swiss Webster model of azoxymethane (AOM)/[[dextran sulfate sodium]] (DSS)-induced [[colitis-associated neoplasia]].
#
# ============================================================
# Unit id: 707283108
#
# EU-ADR answer: speculative
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 1  drug_disease_71    speculative      1.7333          2       0.697983      1
# 0  drug_disease_71       positive      0.7500          1       0.302017      0
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_71  used_to_treat      1.7333          2              1
#
# These data suggest that [[low-dose 5-ASA]] may be efficacious in preventing [[colitis-associated dysplasias]] and provide strong support for optimizing this therapy for the prevention of colonic neoplasms in patients with ulcerative colitis.
#
# ============================================================
# Unit id: 706124904
#
# EU-ADR answer: speculative
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 1  drug_disease_72    speculative      4.3107          5       0.567773      1
# 0  drug_disease_72       positive      3.2816          4       0.432227      0
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_72  used_to_treat      4.3107          5              1
#
# These data suggest that [[low-dose 5-ASA]] may be efficacious in preventing colitis-associated dysplasias and provide strong support for optimizing this therapy for the prevention of [[colonic neoplasms]] in patients with ulcerative colitis.
#
# ============================================================
# Unit id: 706124762
#
# EU-ADR answer: speculative
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 3  drug_disease_73    speculative      4.1809          5       0.540342      1
# 2  drug_disease_73       positive      1.8643          2       0.240943      0
# 0  drug_disease_73          false      0.9231          1       0.119302      0
# 1  drug_disease_73       negative      0.7692          1       0.099412      0
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_73  used_to_treat      4.1809          5              1
#
# These data suggest that [[low-dose 5-ASA]] may be efficacious in preventing colitis-associated dysplasias and provide strong support for optimizing this therapy for the prevention of colonic neoplasms in patients with [[ulcerative colitis]].
#
# ============================================================
# Unit id: 707278758
#
# EU-ADR answer: speculative
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 1  drug_disease_74    speculative      1.8398          2       0.705174      1
# 0  drug_disease_74       positive      0.7692          1       0.294826      0
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_74      may_cause      0.9231          1       0.501739
# 1  drug_disease_74  used_to_treat      0.9167          1       0.498261
#
# The impact of the antiinflammatory agent 5-aminosalicylic acid ([[5-ASA]]) on the risk for [[colitis-associated colorectal cancer]] remains controversial.
#
# ============================================================
# Unit id: 706124843
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_77       positive      2.3034          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_77  used_to_treat      2.3034          3              1
#
# Administration of 75 mg/kg [[5-ASA]] decreased both the mean multiplicity of flat dysplasias (1.8 +/- 0.4 for drug-treated versus 5.6 +/- 1.2 for AOM/DSS control) and the burden of polypoid dysplasias ([[tumor]] burden: 6.7 +/- 2.7 for drug-treated versus 14.9 +/- 3.9 units for AOM/DSS controls) significantly (P = 0.002 and 0.04, respectively).
#
# ============================================================
# Unit id: 706124780
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 1  drug_disease_78       positive      2.5245          3       0.774909      1
# 0  drug_disease_78          false      0.7333          1       0.225091      0
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_78      may_cause      1.6912          2       0.669915
# 1  drug_disease_78  used_to_treat      0.8333          1       0.330085
#
# An inverse trend was observed between dose and multiplicity of colonic dysplasias in all drug-treated groups (P = 0.03), with animals receiving 75 mg/kg [[5-ASA]] exhibiting 56% of the number of [[dysplasias]] of the AOM/DSS controls (mean +/- SEM: 7.6 +/- 1.4 and 13.6 +/- 2.7, respectively).
#
# ============================================================
# Unit id: 706124738
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_79       positive      2.7424          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_79  used_to_treat      2.7424          3              1
#
# Administration of 75 mg/kg [[5-ASA]] decreased both the mean multiplicity of [[flat dysplasias]] (1.8 +/- 0.4 for drug-treated versus 5.6 +/- 1.2 for AOM/DSS control) and the burden of polypoid dysplasias (tumor burden: 6.7 +/- 2.7 for drug-treated versus 14.9 +/- 3.9 units for AOM/DSS controls) significantly (P = 0.002 and 0.04, respectively).
#
# ============================================================
# Unit id: 707287494
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#        pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_8       positive      2.3596          3              1      1
#
#        pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_8      may_cause      2.3596          3              1
#
# We describe the case of a 10-year-old boy who developed [[systemic weakness]] following treatment of spasticity with [[botulinum toxin type B]].
#
# ============================================================
# Unit id: 706124915
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_81       positive      2.6092          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_81      may_cause      1.8015          2       0.690442
# 1  drug_disease_81  used_to_treat      0.8077          1       0.309558
#
# An inverse trend was observed between dose and multiplicity of [[colonic dysplasias]] in all drug-treated groups (P = 0.03), with animals receiving 75 mg/kg [[5-ASA]] exhibiting 56% of the number of dysplasias of the AOM/DSS controls (mean +/- SEM: 7.6 +/- 1.4 and 13.6 +/- 2.7, respectively).
#
# ============================================================
# Unit id: 706124822
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_82       positive      2.3788          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_82      may_cause      1.6515          2       0.694258
# 1  drug_disease_82          other      0.7273          1       0.305742
# [[Spinal cord infarction]] secondary to [[cocaine]] use.
#
# ============================================================
# Unit id: 706124849
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_83       positive      2.5983          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_83      may_cause      2.5983          3              1
#
# [[Cocaine]] abuse is associated with [[cerebrovascular events]]; spinal cord effects are rarely reported.
#
# ============================================================
# Unit id: 706124731
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_84       positive       2.397          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_84      may_cause       2.397          3              1
#
# Although uncommon, [[cocaine]] abuse can cause [[spinal cord infarction]].
#
# ============================================================
# Unit id: 707004997
#
# EU-ADR answer: speculative
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_85    speculative      2.5421          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_85      may_cause      2.5421          3              1
#
# We report two rheumatoid arthritis patients developing [[sarcoidosis]] possibly induced by [[etanercept]].
#
# ============================================================
# Unit id: 706124861
#
# EU-ADR answer: speculative
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_90    speculative      2.3596          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_90          other      1.5904          2       0.674013
# 0  drug_disease_90      may_cause      0.7692          1       0.325987
#
# Furthermore, there may be a relationship between [[statin]] dose and [[cancer]].
#
# ============================================================
# Unit id: 706124891
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_93       positive       2.609          3              1      1
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_93  used_to_treat       2.609          3              1
#
# [[BiRD]] is an effective regimen with manageable side effects in the treatment of symptomatic, newly diagnosed [[multiple myeloma]].
#
# ============================================================
# Unit id: 706124850
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 1  drug_disease_95       positive      4.9582          6       0.668672      1
# 2  drug_disease_95    speculative      1.6568          2       0.223439      0
# 0  drug_disease_95          false      0.8000          1       0.107889      0
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_95  used_to_treat      4.1011          5       0.827135
# 0  drug_disease_95          other      0.8571          1       0.172865
#
# A multipronged approach to limit [[endophthalmitis]] risk is also needed, with [[antibiotics]] as only part of the strategy.
#
# ============================================================
# Unit id: 707286886
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_96       positive      2.5126          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_96  used_to_treat      2.5126          3              1
#
# In this study, a 2-year-old girl with [[nephropathic cystinosis]] and severe gastrointestinal dysmotility was treated with intravenous ([[i.v.) administration of cysteamine hydrochloride]] (HCl).
#
# ============================================================
# Unit id: 707283447
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_97       positive        2.85          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_97      may_cause        2.85          3              1
#
# The most common adverse effects associated with the use of [[posaconazole]] include headache, fever, nausea, vomiting, and [[diarrhea]].
#
# ============================================================
# Unit id: 706124817
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_98       positive      2.4564          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_98  used_to_treat      2.4564          3              1
#
# [[Posaconazole]] is noninferior to fluconazole for treatment of [[oropharyngeal candidiasis]] (95% CI -6.6 to 5.0), but necessity for this indication remains unclear, as many other treatment options exist.
#
# ============================================================
# Unit id: 706124681
# EU-ADR answer: positive
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 2  drug_disease_99       positive      4.4928          5       0.589367      1
# 0  drug_disease_99          false      1.6278          2       0.213535      0
# 1  drug_disease_99       negative      1.5025          2       0.197098      0
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_99  used_to_treat      4.4928          5              1
#
# Similarly, the same regimen of posaconazole reduced invasive fungal infections (95% CI -9.7 to -2.5) and [[aspergillosis]] (CI not reported, p < 0.001) when compared with fluconazole and [[itraconazole]] in neutropenic patients.
#
# ============================================================

# %% [markdown]
# Deep semantics agreement percentage for top choice:

# %%
temp = []
for rel_id, group in deep_sem_res.groupby("pub_rel_id"):
    temp.append(group.iloc[0]["percent_agree"])
    
graph = pd.Series(sorted(temp)).plot()
graph.set_ylim((0, 1.1))
# Out:
# (0, 1.1)

# %%
temp = []
for rel_id, group in deep_sem_res.groupby("pub_rel_id"):
    if group.iloc[0]["percent_agree"] < 0.8:
        temp.append((rel_id, group.iloc[0]["percent_agree"]))
        
temp = sorted(temp, key = lambda x: x[1])


summary(map(lambda x: x[0], temp))
# Out:
# Unit id: 706124806
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_38       positive      2.4245          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 2  drug_disease_38  used_to_treat      0.9412          1       0.388204
# 0  drug_disease_38      may_cause      0.7500          1       0.309342
# 1  drug_disease_38          other      0.7333          1       0.302454
#
# In addition, when the [[glioma]] cells were exposed to 25 microM of [[indomethacin-loaded nanocapsules]] or indomethacin ethyl ester-loaded nanocapsules, a necrotic cell death was observed.
#
# ============================================================
# Unit id: 707278758
#
# EU-ADR answer: speculative
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 1  drug_disease_74    speculative      1.8398          2       0.705174      1
# 0  drug_disease_74       positive      0.7692          1       0.294826      0
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_74      may_cause      0.9231          1       0.501739
# 1  drug_disease_74  used_to_treat      0.9167          1       0.498261
#
# The impact of the antiinflammatory agent 5-aminosalicylic acid ([[5-ASA]]) on the risk for [[colitis-associated colorectal cancer]] remains controversial.
#
# ============================================================
# Unit id: 706124771
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 2  drug_disease_39       positive      3.3362          4       0.447092      1
# 1  drug_disease_39       negative      2.5743          3       0.344988      0
# 3  drug_disease_39    speculative      0.8182          1       0.109649      0
# 0  drug_disease_39          false      0.7333          1       0.098271      0
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 2  drug_disease_39  used_to_treat      1.6904          2       0.506684
# 1  drug_disease_39          other      0.8333          1       0.249775
# 0  drug_disease_39      may_cause      0.8125          1       0.243541
#
# Another important finding was that the cytotoxic effect induced by 25 microM or 50 microM of indomethacin-loaded nanocapsules or [[indomethacin ethyl ester-loaded nanocapsules]], in [[glioma]] cells was not observed in the organotypic cultures, indicating selective cytotoxicity of those formulations for tumoral cells.
#
# ============================================================
# Unit id: 706124912
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_168       positive      1.6648          2       0.689415
# 1  drug_disease_168    speculative      0.7500          1       0.310585
#
#    match
# 0      1
# 1      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_168  used_to_treat      0.8571          1       0.514837
# 0  drug_disease_168      may_cause      0.8077          1       0.485163
#
# To determine [[cancer]] risk in a cohort of 459 rheumatoid arthritis (RA) patients treated with [[methotrexate]] in community practice.
#
# ============================================================
# Unit id: 706124856
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_213       positive      1.6648          2       0.689415
# 1  drug_disease_213    speculative      0.7500          1       0.310585
#
#    match
# 0      1
# 1      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_213          other      0.8571          1       0.514837
# 1  drug_disease_213  used_to_treat      0.8077          1       0.485163
# At all doses studied, [[febuxostat]] more effectively lowered and maintained serum urate levels <6.0 mg/dl than did allopurinol (300 or 100 mg) or placebo in subjects with hyperuricemia and gout, including those with mild to moderately [[impaired renal function]].
#
# ============================================================
# Unit id: 706124917
#
# EU-ADR answer: speculative
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 1  drug_disease_115    speculative      4.8437          6       0.655733
# 0  drug_disease_115       positive      2.5430          3       0.344267
#
#    match
# 1      1
# 0      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_115  used_to_treat      2.5165          3       0.519541
# 0  drug_disease_115      may_cause      2.3272          3       0.480459
#
# While some beneficial neuromotor effects of succimer therapy were observed in the present study there remains several unanswered questions such as how long these effects will persist and how [[succimer]] therapy modifies lead-associated [[cerebellar deficits]] manifesting as perturbations in vestibular and/or proprioception systems for postural balance and functional locomotion.
#
# ============================================================
# Unit id: 706124846
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 1  drug_disease_26       positive      1.7594          2       0.707524      1
# 0  drug_disease_26          false      0.7273          1       0.292476      0
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_26  used_to_treat      0.9412          1       0.534955
# 0  drug_disease_26          other      0.8182          1       0.465045
#
# Intra-articular injection of lidocaine before closed reduction of anterior shoulder dislocation produces the same [[pain]] relief as intravenous meperidine and [[diazepam]].
#
# ============================================================
# Unit id: 706124696
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_56       positive      2.7424          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_56      may_cause      1.7424          2       0.635356
# 1  drug_disease_56  used_to_treat      1.0000          1       0.364644
#
# Calculated detectable differences for mortality/[[fatal malignancy]] with respect to the general population are 22%/49% for [[antimetabolites]], 28%/62% for T-cell inhibitors, and 36%/81% for alkylating agents.
#
# ============================================================
# Unit id: 706124899
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_63       positive      2.3596          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_63      may_cause      1.5025          2        0.63676
# 1  drug_disease_63  used_to_treat      0.8571          1        0.36324
#
# There were consistent significant [[miosis]] in the right eyes with instilled [[Garcinia kola nut extract]] compared to the left eyes at 15, 30 and 45 minutes (p=0.0000).
#
# ============================================================
# Unit id: 706124726
# EU-ADR answer: positive
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 1  drug_disease_29       positive      2.5971          3       0.757084      1
# 0  drug_disease_29          false      0.8333          1       0.242916      0
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_29  used_to_treat      1.6559          2       0.637596
# 0  drug_disease_29      may_cause      0.9412          1       0.362404
#
# Mean [[pain]] (mm) recorded before injection, before reduction, and after reduction in the [[intra-articular lidocaine]] group was 84.3 (95% confidence interval (CI) 79.8 to 88.8), 52.6 (95% CI 45.2 to 60.1), and 27.3 (95% CI 19.9 to 34.7), respectively.
#
# ============================================================
# Unit id: 706124734
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_225       positive      2.5589          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_225      may_cause      1.6498          2        0.64473
# 1  drug_disease_225          other      0.9091          1        0.35527
#
# [[Pulmonary alveolar proteinosis]]: a rare pulmonary toxicity of [[sirolimus]].
#
# ============================================================
# Unit id: 706124821
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_113       positive      2.4848          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_113  used_to_treat      1.6515          2       0.664641
# 0  drug_disease_113      may_cause      0.8333          1       0.335359
#
# Posaconazole, in doses of 200 mg 3 times daily, reduced breakthrough [[invasive fungal infections]] (OR 0.30; 95% CI 0.12 to 0.71) and aspergillosis incidence (OR 0.31; 95% CI 0.13 to 0.75) in patients receiving hematopoietic stem-cell transplants compared with those receiving [[fluconazole]].
#
# ============================================================
# Unit id: 706124721
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_170       positive      2.4892          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_170      may_cause      1.6559          2       0.665234
# 1  drug_disease_170  used_to_treat      0.8333          1       0.334766
#
# Incidence of [[melanoma]] and other malignancies among rheumatoid arthritis patients treated with [[methotrexate]].
#
# ============================================================
# Unit id: 706124733
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_42       positive      2.4892          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_42  used_to_treat      1.6559          2       0.665234
# 0  drug_disease_42      may_cause      0.8333          1       0.334766
# Indomethacin and [[indomethacin ethyl ester]] associated together in the same nanocapsule formulation caused a synergic effect decreasing [[glioma]] cell proliferation.
#
# ============================================================
# Unit id: 706694486
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_22       positive      2.4148          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_22  used_to_treat      1.6071          2       0.665521
# 0  drug_disease_22      may_cause      0.8077          1       0.334479
#
# The combination of [[high-dose MTX]] with procarbazine and CCNU is feasible and effective and results in a low rate of [[leukoencephalopathy]].
#
# ============================================================
# Unit id: 706124831
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_211       positive      2.4999          3       0.753413
# 1  drug_disease_211    speculative      0.8182          1       0.246587
#
#    match
# 0      1
# 1      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_211      may_cause      1.6666          2       0.666667
# 1  drug_disease_211  used_to_treat      0.8333          1       0.333333
#
# The primary reasons for withdrawal were similar across groups except for [[gout flares]], which were more frequent with febuxostat than with [[allopurinol]].
#
# ============================================================
# Unit id: 706124698
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_30       positive      2.4686          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_30  used_to_treat      1.6504          2       0.668557
# 0  drug_disease_30      may_cause      0.8182          1       0.331443
#
# [[Intra-articular injection of lidocaine]] before closed reduction of anterior shoulder dislocation produces the same [[pain]] relief as intravenous meperidine and diazepam.
#
# ============================================================
# Unit id: 707280277
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_194       positive      2.5879          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_194  used_to_treat      1.7308          2       0.668805
# 0  drug_disease_194      may_cause      0.8571          1       0.331195
#
# This study demonstrated that both low-dose [[topiramate]] and propranolol could significantly reduce [[migraine headache]] frequency, intensity, and duration.
#
# ============================================================
# Unit id: 706124863
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_209       positive      2.5879          3              1
#
#    match
# 0      1
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_209  used_to_treat      1.7308          2       0.668805
# 0  drug_disease_209      may_cause      0.8571          1       0.331195
#
# At all doses studied, febuxostat more effectively lowered and maintained serum urate levels <6.0 mg/dl than did [[allopurinol]] (300 or 100 mg) or placebo in subjects with [[hyperuricemia]] and gout, including those with mild to moderately impaired renal function.
#
# ============================================================
# Unit id: 706124780
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 1  drug_disease_78       positive      2.5245          3       0.774909      1
# 0  drug_disease_78          false      0.7333          1       0.225091      0
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_78      may_cause      1.6912          2       0.669915
# 1  drug_disease_78  used_to_treat      0.8333          1       0.330085
#
# An inverse trend was observed between dose and multiplicity of colonic dysplasias in all drug-treated groups (P = 0.03), with animals receiving 75 mg/kg [[5-ASA]] exhibiting 56% of the number of [[dysplasias]] of the AOM/DSS controls (mean +/- SEM: 7.6 +/- 1.4 and 13.6 +/- 2.7, respectively).
#
# ============================================================
# Unit id: 706124682
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_59       positive       2.397          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_59      may_cause      1.6113          2       0.672215
# 1  drug_disease_59  used_to_treat      0.7857          1       0.327785
#
# Calculated detectable differences for mortality/[[fatal malignancy]] with respect to the general population are 22%/49% for antimetabolites, 28%/62% for [[T-cell inhibitors]], and 36%/81% for alkylating agents.
#
# ============================================================
# Unit id: 706124861
#
# EU-ADR answer: speculative
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_90    speculative      2.3596          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_90          other      1.5904          2       0.674013
# 0  drug_disease_90      may_cause      0.7692          1       0.325987
#
# Furthermore, there may be a relationship between [[statin]] dose and [[cancer]].
#
# ============================================================
# Unit id: 706124794
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_154       positive      2.4745          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_154  used_to_treat      1.6745          2       0.676702
# 0  drug_disease_154      may_cause      0.8000          1       0.323298
#
# Administration of full-dose R-CHOP (rituximab/cyclophosphamide/doxorubicin/vincristine/[[prednisone]]) chemotherapy is important to maximize response in patients with intermediate-or [[high-grade non-Hodgkin lymphoma]] but might be difficult in older patients.
#
# ============================================================
# Unit id: 706124740
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_151       positive       2.397          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_151  used_to_treat      1.6278          2       0.679099
# 0  drug_disease_151      may_cause      0.7692          1       0.320901
#
# Plasma [[ziprasidone]] levels ranged from 20 ng/mL to 160 ng/mL (mean: 75.8 ng/mL) and were significantly related to the improvement in [[negative symptoms]].
#
# ============================================================
# Unit id: 706124812
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_145       positive      2.5873          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_145  used_to_treat      1.7748          2       0.685966
# 0  drug_disease_145      may_cause      0.8125          1       0.314034
#
# Forty-one patients [30 males and 11 females, median age 47 years] consecutively diagnosed with [[PTCL]] received three courses of high-dose cyclophosphamide 2000 mg/m(2)/day, [[adriamycin]] 90 mg/m(2)/day, vincristine and prednisone alternating with three courses of etoposide, cisplatin, cytarabine and prednisone.
#
# ============================================================
# Unit id: 706124820
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_147       positive      2.5873          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_147  used_to_treat      1.7748          2       0.685966
# 0  drug_disease_147      may_cause      0.8125          1       0.314034
#
# Forty-one patients [30 males and 11 females, median age 47 years] consecutively diagnosed with [[PTCL]] received three courses of high-dose cyclophosphamide 2000 mg/m(2)/day, adriamycin 90 mg/m(2)/day, vincristine and prednisone alternating with three courses of etoposide, cisplatin, cytarabine and [[prednisone]].
#
# ============================================================
# Unit id: 706124707
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_50       positive      2.4004          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_50  used_to_treat      1.6504          2       0.687552
# 0  drug_disease_50      may_cause      0.7500          1       0.312448
#
# Although the role of [[clozapine]] is well established for [[treatment-resistant schizophrenia]], it is rarely used in pediatric populations, mainly due to its potentially serious adverse effects.
#
# ============================================================
# Unit id: 706124828
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_169       positive      2.5666          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_169      may_cause      1.7666          2       0.688304
# 1  drug_disease_169  used_to_treat      0.8000          1       0.311696
#
# Incidence of melanoma and other [[malignancies]] among rheumatoid arthritis patients treated with [[methotrexate]].
#
# ============================================================
# Unit id: 706124719
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_141       positive      2.6754          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_141  used_to_treat      1.8421          2       0.688533
# 0  drug_disease_141      may_cause      0.8333          1       0.311467
#
# An open multicenter phase II trial of weekly [[docetaxel]] for [[advanced-stage non-small-cell lung cancer]] in elderly patients with significant comorbidity and/or poor performance status: The GFPC 02-02b study.
#
# ============================================================
# Unit id: 706124894
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_167       positive      2.6836          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_167  used_to_treat      1.8503          2       0.689484
# 0  drug_disease_167      may_cause      0.8333          1       0.310516
#
# To determine cancer risk in a cohort of 459 [[rheumatoid arthritis]] (RA) patients treated with [[methotrexate]] in community practice.
#
# ============================================================
# Unit id: 706124910
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_32       positive      2.6836          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_32  used_to_treat      1.8503          2       0.689484
# 0  drug_disease_32      may_cause      0.8333          1       0.310516
#
# Another important finding was that the cytotoxic effect induced by 25 microM or 50 microM of [[indomethacin-loaded nanocapsules]] or indomethacin ethyl ester-loaded nanocapsules, in [[glioma]] cells was not observed in the organotypic cultures, indicating selective cytotoxicity of those formulations for tumoral cells.
#
# ============================================================
# Unit id: 706124889
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_36       positive      2.6836          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_36  used_to_treat      1.8503          2       0.689484
# 0  drug_disease_36      may_cause      0.8333          1       0.310516
#
# In addition, when the [[glioma]] cells were exposed to 25 microM of indomethacin-loaded nanocapsules or [[indomethacin ethyl ester-loaded nanocapsules]], a necrotic cell death was observed.
#
# ============================================================
# Unit id: 706124892
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#        pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_7       positive      2.6836          3              1      1
#
#        pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_7  used_to_treat      1.8503          2       0.689484
# 0  drug_disease_7      may_cause      0.8333          1       0.310516
# We describe the case of a 10-year-old boy who developed systemic weakness following treatment of [[spasticity]] with [[botulinum toxin type B]].
#
# ============================================================
# Unit id: 706124858
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_159       positive      2.6092          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_159      may_cause      1.8015          2       0.690442
# 1  drug_disease_159  used_to_treat      0.8077          1       0.309558
#
# Compared with the general population, [[methotrexate]]-treated RA patients have an increased incidence of melanoma, non-Hodgkin's lymphoma, and [[lung cancer]].
#
# ============================================================
# Unit id: 706124874
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_25       positive      2.6092          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_25  used_to_treat      1.8015          2       0.690442
# 0  drug_disease_25      may_cause      0.8077          1       0.309558
#
# Intra-articular injection of lidocaine before closed reduction of anterior shoulder dislocation produces the same [[pain]] relief as [[intravenous meperidine]] and diazepam.
#
# ============================================================
# Unit id: 706124915
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_81       positive      2.6092          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_81      may_cause      1.8015          2       0.690442
# 1  drug_disease_81  used_to_treat      0.8077          1       0.309558
#
# An inverse trend was observed between dose and multiplicity of [[colonic dysplasias]] in all drug-treated groups (P = 0.03), with animals receiving 75 mg/kg [[5-ASA]] exhibiting 56% of the number of dysplasias of the AOM/DSS controls (mean +/- SEM: 7.6 +/- 1.4 and 13.6 +/- 2.7, respectively).
#
# ============================================================
# Unit id: 706124830
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_110       positive      2.3788          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_110  used_to_treat      1.6515          2       0.694258
# 0  drug_disease_110          other      0.7273          1       0.305742
#
# [[Posaconazole]], in doses of 200 mg 3 times daily, reduced breakthrough invasive fungal infections (OR 0.30; 95% CI 0.12 to 0.71) and [[aspergillosis]] incidence (OR 0.31; 95% CI 0.13 to 0.75) in patients receiving hematopoietic stem-cell transplants compared with those receiving fluconazole.
#
# ============================================================
# Unit id: 706124798
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_27       positive      2.3788          3              1      1
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_27  used_to_treat      1.6515          2       0.694258
# 0  drug_disease_27          other      0.7273          1       0.305742
#
# Intra-articular injection of lidocaine before closed reduction of [[anterior shoulder dislocation]] produces the same pain relief as intravenous meperidine and [[diazepam]].
#
# ============================================================
# Unit id: 706124822
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_82       positive      2.3788          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_82      may_cause      1.6515          2       0.694258
# 1  drug_disease_82          other      0.7273          1       0.305742
#
# [[Spinal cord infarction]] secondary to [[cocaine]] use.
#
# ============================================================
# Unit id: 706124879
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_231       positive      2.4833          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_231  used_to_treat      1.7333          2       0.697983
# 0  drug_disease_231      may_cause      0.7500          1       0.302017
#
# We concluded that conversion to SRL in pancreas transplantation should be considered an important alternative strategy, particularly for CNI nephrotoxicity and neurotoxicity, and in cases of [[severe diarrhea]] due to [[MMF]].
#
# ============================================================
# Unit id: 706124716
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_192       positive      2.4221          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_192      may_cause      1.6948          2       0.699723
# 1  drug_disease_192  used_to_treat      0.7273          1       0.300277
#
# The most frequent and the most troublesome adverse effect of interferon plus [[ribavirin]]-based therapy is [[anaemia]].
#
# ============================================================
# Unit id: 706124895
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_240       positive       2.609          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_240  used_to_treat      1.8398          2       0.705174
# 0  drug_disease_240      may_cause      0.7692          1       0.294826
#
# Oral BDP prevents [[relapses of gastrointestinal GVHD]] following tapering of [[prednisone]]; survival is statistically significantly better among patients receiving BDP.
#
# ============================================================
# Unit id: 706124815
# EU-ADR answer: positive
# Experts agree: 3/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_216       positive      2.5078          3              1
#
#    match
# 0      1
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_216      may_cause      1.7745          2       0.707592
# 1  drug_disease_216  used_to_treat      0.7333          1       0.292408
#
# The primary reasons for withdrawal were similar across groups except for [[gout flares]], which were more frequent with [[febuxostat]] than with allopurinol.
#
# ============================================================
# Unit id: 706124706
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_33       positive      3.9401          5       0.536703      1
# 1  drug_disease_33    speculative      3.4012          4       0.463297      0
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_33  used_to_treat      3.1068          4       0.788508
# 0  drug_disease_33      may_cause      0.8333          1       0.211492
#
# Selective cytotoxicity of [[indomethacin]] and indomethacin ethyl ester-loaded nanocapsules against [[glioma]] cell lines: an in vitro study.
#
# ============================================================
# Unit id: 706124782
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 2  drug_disease_64       positive      4.1098          5       0.556567      1
# 0  drug_disease_64          false      2.4619          3       0.333401      0
# 1  drug_disease_64       negative      0.8125          1       0.110032      0
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_64          other      3.2636          4       0.794102
# 1  drug_disease_64  used_to_treat      0.8462          1       0.205898
#
# There is evidence in the literature that inhaled corticosteroids ([[ICSs]]) are safe for pregnant women with [[asthma]] and their infants.
#
# ============================================================

# %% [markdown]
# Which work units had other as the top deep semantic choice?

# %%
temp = []
for rel_id, group in deep_sem_res.groupby("pub_rel_id"):
    if group.iloc[0]["deep_semantics"] == "other":
        temp.append((rel_id, group.iloc[0]["percent_agree"]))
        
temp = sorted(temp, key = lambda x: x[1])


summary(map(lambda x: x[0], temp))
# Out:
# Unit id: 706124856
#
# EU-ADR answer: positive
# Experts agree: 2/3
#
#          pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  \
# 0  drug_disease_213       positive      1.6648          2       0.689415
# 1  drug_disease_213    speculative      0.7500          1       0.310585
#
#    match
# 0      1
# 1      0
#
#          pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_213          other      0.8571          1       0.514837
# 1  drug_disease_213  used_to_treat      0.8077          1       0.485163
#
# At all doses studied, [[febuxostat]] more effectively lowered and maintained serum urate levels <6.0 mg/dl than did allopurinol (300 or 100 mg) or placebo in subjects with hyperuricemia and gout, including those with mild to moderately [[impaired renal function]].
#
# ============================================================
# Unit id: 706124861
#
# EU-ADR answer: speculative
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 0  drug_disease_90    speculative      2.3596          3              1      1
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 1  drug_disease_90          other      1.5904          2       0.674013
# 0  drug_disease_90      may_cause      0.7692          1       0.325987
#
# Furthermore, there may be a relationship between [[statin]] dose and [[cancer]].
#
# ============================================================
# Unit id: 706124782
#
# EU-ADR answer: positive
# Experts agree: 3/3
#
#         pub_rel_id broad_rel_type  conf_score  num_votes  percent_agree  match
# 2  drug_disease_64       positive      4.1098          5       0.556567      1
# 0  drug_disease_64          false      2.4619          3       0.333401      0
# 1  drug_disease_64       negative      0.8125          1       0.110032      0
#
#         pub_rel_id deep_semantics  conf_score  num_votes  percent_agree
# 0  drug_disease_64          other      3.2636          4       0.794102
# 1  drug_disease_64  used_to_treat      0.8462          1       0.205898
#
# There is evidence in the literature that inhaled corticosteroids ([[ICSs]]) are safe for pregnant women with [[asthma]] and their infants.
#
# ============================================================
