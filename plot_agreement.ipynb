# %% [markdown]
# Plot expert agreement with regular agreement

# %% [markdown]
# ONly for the work units where the crowd answer matched the experts

# %%
from itertools import islice
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np

# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
sys.path.append("/home/toby/crowdsourcing/drug_disease_semantics/src/")

from filter_data import filter_data
from true_relation_type import get_euadr_relation_type

from aggregate_votes import aggregate_votes

from collections import defaultdict

# %%
settings = {
    "loc": "/home/toby/crowdsourcing/drug_disease_semantics/data",
    "fname": "job_710587_full_with_untrusted.tsv",
    "data_subset": "normal",
    "min_accuracy": 0.7,
    "max_accuracy": 1.0,
    "sentence_type": "all"
}

raw_data = filter_data(settings)
euadr_answer = get_euadr_relation_type(settings)

# %%
raw_data.columns.values
# Out:
# array(['_unit_id', '_created_at', '_golden', '_id', '_missed',
#        '_started_at', '_tainted', '_channel', '_trust', '_worker_id',
#        '_country', '_region', '_city', '_ip', 'broad_rel_type',
#        'comments_box', 'deep_semantics', 'broad_rel_type_gold',
#        'data_subset', 'deep_semantics_gold', 'form_object', 'form_subject',
#        'formatted_sentence', 'gold_std_association_type', 'num_sentence',
#        'object_end', 'object_start', 'object_text', 'object_type',
#        'original_sentence', 'pubmed_id', 'subject_end', 'subject_start',
#        'subject_text', 'subject_type'], dtype=object)

# %%
def matches(gold_ans, crowd_ans):
    return int(gold_ans == crowd_ans)

def determine_broad_reltype_results(true_relation_type, data):
    """
    Calculates the agreement percentage and determines whether the
    top crowd response matches the gold standard for all work units.
    """
    result = []
    for unit_id, group in data.groupby("_unit_id"):
        ans = aggregate_votes("broad_rel_type", group)

        total_vote_score = sum(ans["conf_score"])
        percent_agreement = ans["conf_score"] / total_vote_score
        
        match = [matches(true_relation_type[unit_id], val) for val in ans["broad_rel_type"]]

        ans.insert(len(ans.columns), "percent_agreement", percent_agreement)
        ans.insert(len(ans.columns), "match", match)
        ans.insert(0, "unit_id", unit_id)

        ans = ans.sort(["conf_score"], ascending = False)

        result.append(ans)

    return pd.concat(result)

# %%
results = determine_broad_reltype_results(euadr_answer, raw_data)

# %%
for unit_id, group in results.groupby("unit_id"):
    print group
    print
# Out:
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698757970       positive      6.8960          8           0.808280      0
# 0  698757970          false      0.8500          1           0.099628      1
# 2  698757970    speculative      0.7857          1           0.092092      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698757972       negative      3.5375          4           0.403552      0
# 2  698757972       positive      2.7802          3           0.317161      0
# 0  698757972          false      1.6357          2           0.186598      1
# 3  698757972    speculative      0.8125          1           0.092689      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698757975          false      7.9534          9           0.907311      1
# 1  698757975       positive      0.8125          1           0.092689      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698757976       positive      6.7906          8           0.795926      0
# 2  698757976    speculative      0.9286          1           0.108841      0
# 0  698757976          false      0.8125          1           0.095233      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698757977       positive      6.9556          8           0.801281      0
# 1  698757977    speculative      1.7250          2           0.198719      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698757978       positive      6.0585          7           0.710116      1
# 0  698757978          false      1.5982          2           0.187325      0
# 2  698757978    speculative      0.8750          1           0.102559      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698757979       positive      7.1161          8           0.812164      1
# 2  698757979    speculative      0.8333          1           0.095105      0
# 0  698757979          false      0.8125          1           0.092731      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698757980       positive      5.2337          6           0.607496      1
# 2  698757980    speculative      1.7833          2           0.206995      0
# 0  698757980          false      1.5982          2           0.185509      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 2  698757981       positive      4.3905          5           0.498835      1
# 0  698757981          false      3.6610          4           0.415952      0
# 1  698757981       negative      0.7500          1           0.085213      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698757982       positive       9.105         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698757983       positive      8.6152         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 2  698757984    speculative      4.4782          5           0.519802      0
# 1  698757984       positive      2.5013          3           0.290336      1
# 0  698757984          false      1.6357          2           0.189862      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698757985       positive      8.7571         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 2  698757986       positive      3.5699          4           0.404274      1
# 0  698757986          false      3.4819          4           0.394308      0
# 3  698757986    speculative      0.9286          1           0.105159      0
# 1  698757986       negative      0.8500          1           0.096258      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 2  698757987       positive      6.3978          7           0.718555      1
# 0  698757987          false      0.9286          1           0.104294      0
# 3  698757987    speculative      0.8500          1           0.095466      0
# 1  698757987       negative      0.7273          1           0.081685      0
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698757988       positive      3.5266          4           0.409346      1
# 2  698757988    speculative      2.6404          3           0.306482      0
# 0  698757988          false      2.4482          3           0.284172      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 2  698757989    speculative      5.9840          7           0.683331      0
# 1  698757989       positive      1.9231          2           0.219605      1
# 0  698757989          false      0.8500          1           0.097064      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698757990       positive      8.9037         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 2  698757991       positive      4.5302          5           0.497551      0
# 0  698757991          false      2.7248          3           0.299264      1
# 1  698757991       negative      1.8500          2           0.203185      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698757992       positive      4.3875          5           0.511340      1
# 0  698757992          false      3.4429          4           0.401252      0
# 2  698757992    speculative      0.7500          1           0.087409      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698757993       positive      8.7659         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698757994       positive      8.7659         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698757996       positive      7.8056          9           0.899201      1
# 1  698757996    speculative      0.8750          1           0.100799      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698757997       positive      7.9842          9           0.904172      1
# 0  698757997       negative      0.8462          1           0.095828      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698757998       positive      8.5317         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698757999       positive      6.0583          7            0.69971      1
# 1  698757999    speculative      2.6000          3            0.30029      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698758000       positive      4.9197          6           0.590168      1
# 0  698758000       negative      3.4164          4           0.409832      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698758002       positive      8.9037         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698758003       positive      8.6583         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698758004       positive      8.6806         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698758005       positive      6.1295          7           0.711475      1
# 2  698758005    speculative      1.6357          2           0.189862      0
# 0  698758005          false      0.8500          1           0.098663      0
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698758006       negative      4.3890          5           0.498665      0
# 2  698758006       positive      3.5625          4           0.404761      0
# 0  698758006          false      0.8500          1           0.096574      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698758008       positive      6.6679          8           0.799882      0
# 0  698758008       negative      0.8500          1           0.101966      0
# 2  698758008    speculative      0.8182          1           0.098151      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698758009       positive      9.2635         11           0.912444      1
# 1  698758009    speculative      0.8889          1           0.087556      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698758010       positive      6.1282          7           0.696268      0
# 1  698758010    speculative      2.6733          3           0.303732      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698758011       positive       8.105          9            0.89017      0
# 1  698758011    speculative       1.000          1            0.10983      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698758012       positive      8.7571         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698758013       positive       9.105         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698758014          false      4.2872          5           0.514293      0
# 1  698758014       negative      2.3864          3           0.286273      0
# 2  698758014       positive      0.8500          1           0.101966      1
# 3  698758014    speculative      0.8125          1           0.097468      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698758015       positive      8.7619         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698758016       positive      8.6583         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698758017       positive      6.9068          8            0.78473      0
# 1  698758017    speculative      1.8947          2            0.21527      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698758018       positive      6.0585          7           0.710116      1
# 0  698758018          false      2.4732          3           0.289884      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698758020       positive      4.5643          5           0.501296      0
# 1  698758020    speculative      4.5407          5           0.498704      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698758022       positive      8.6806         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 2  698758023       positive      6.6997          8           0.803697      1
# 0  698758023          false      0.8182          1           0.098151      0
# 1  698758023       negative      0.8182          1           0.098151      0
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698758024       positive      5.4381          6           0.620993      1
# 0  698758024          false      2.4857          3           0.283850      0
# 2  698758024    speculative      0.8333          1           0.095157      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698758025       positive      7.7833          9           0.898941      1
# 0  698758025          false      0.8750          1           0.101059      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698758026    speculative      4.5405          5            0.51821      0
# 0  698758026       positive      4.2214          5            0.48179      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698758027       positive      5.9119          7           0.674728      0
# 1  698758027    speculative      2.8500          3           0.325272      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698758028    speculative      5.3191          6            0.60434      0
# 0  698758028       positive      3.4824          4            0.39566      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698936313       positive      8.0537          9           0.904534      1
# 0  698936313          false      0.8500          1           0.095466      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698936583       positive      8.9037         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698936792       positive      7.7571          9           0.885807      1
# 1  698936792    speculative      1.0000          1           0.114193      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698937471       positive      8.6583         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698937671       positive      8.7659         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698937904          false      8.7619         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698939052          false      6.6736          8           0.800566      1
# 1  698939052       negative      1.6625          2           0.199434      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 1  698939741    speculative      6.9804          8           0.813529      1
# 0  698939741          false      1.6000          2           0.186471      0
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 0  698942095       negative      8.5804         10                  1      1
#
#      unit_id broad_rel_type  conf_score  num_votes  percent_agreement  match
# 2  698942663    speculative      7.0806          8           0.815681      1
# 1  698942663       positive      0.8500          1           0.097919      0
# 0  698942663          false      0.7500          1           0.086400      0

# %%
sys.path.append("/home/toby/global_util/")
from file_util import read_file

# %%
id_mapping = dict()
for line in read_file("unit_id_mapping.txt"):
    unit_id, toby_id = line.split('|')
    
    id_mapping[unit_id] = toby_id

# %%
raw_toby_mapping = dict()
for line in islice(read_file("raw_to_toby_mapping.txt"), 1, None):
    toby_id, raw_rel_id, num_agree = line.split('|')
    raw_toby_mapping[toby_id] = (raw_rel_id, num_agree)

# %%
raw_toby_mapping
# Out:
# {'drug_disease_0': ('t_17897305_rel_1', '3'),
#  'drug_disease_1': ('t_18042885_rel_1', '2'),
#  'drug_disease_10': ('t_17274718_rel_5', '2'),
#  'drug_disease_100': ('t_18713852_rel_16', '2'),
#  'drug_disease_101': ('t_18713852_rel_7', '3'),
#  'drug_disease_102': ('t_18713852_rel_8', '3'),
#  'drug_disease_103': ('t_18713852_rel_2', '3'),
#  'drug_disease_104': ('t_18713852_rel_3', '3'),
#  'drug_disease_105': ('t_18713852_rel_6', '3'),
#  'drug_disease_106': ('t_18713852_rel_11', '3'),
#  'drug_disease_107': ('t_18713852_rel_10', '2'),
#  'drug_disease_108': ('t_18713852_rel_14', '2'),
#  'drug_disease_109': ('t_18713852_rel_15', '2'),
#  'drug_disease_11': ('t_17274718_rel_3', '3'),
#  'drug_disease_110': ('t_18713852_rel_0', '3'),
#  'drug_disease_111': ('t_18713852_rel_1', '3'),
#  'drug_disease_112': ('t_18713852_rel_5', '3'),
#  'drug_disease_113': ('t_18713852_rel_12', '2'),
#  'drug_disease_114': ('t_18713852_rel_13', '2'),
#  'drug_disease_115': ('t_17499360_rel_1', '2'),
#  'drug_disease_116': ('t_18395883_rel_1', '2'),
#  'drug_disease_117': ('t_17484031_rel_0', '3'),
#  'drug_disease_118': ('t_17634547_rel_0', '2'),
#  'drug_disease_119': ('t_17634547_rel_2', '2'),
#  'drug_disease_12': ('t_17274718_rel_4', '3'),
#  'drug_disease_120': ('t_17634547_rel_3', '2'),
#  'drug_disease_121': ('t_17894421_rel_5', '1'),
#  'drug_disease_122': ('t_17894421_rel_1', '2'),
#  'drug_disease_123': ('t_17894421_rel_2', '2'),
#  'drug_disease_124': ('t_17894421_rel_6', '2'),
#  'drug_disease_125': ('t_17894421_rel_4', '2'),
#  'drug_disease_126': ('t_19117254_rel_0', '3'),
#  'drug_disease_127': ('t_18230056_rel_0', '3'),
#  'drug_disease_128': ('t_18208910_rel_7', '3'),
#  'drug_disease_129': ('t_18208910_rel_3', '2'),
#  'drug_disease_13': ('t_17274718_rel_2', '2'),
#  'drug_disease_130': ('t_18208910_rel_2', '2'),
#  'drug_disease_131': ('t_18586644_rel_2', '2'),
#  'drug_disease_132': ('t_18586644_rel_3', '2'),
#  'drug_disease_133': ('t_18586644_rel_1', '2'),
#  'drug_disease_134': ('t_18586644_rel_0', '2'),
#  'drug_disease_135': ('t_19135998_rel_1', '2'),
#  'drug_disease_136': ('t_19135998_rel_2', '3'),
#  'drug_disease_137': ('t_19135998_rel_0', '2'),
#  'drug_disease_138': ('t_18058121_rel_0', '2'),
#  'drug_disease_139': ('t_18058121_rel_2', '3'),
#  'drug_disease_14': ('t_17274718_rel_0', '2'),
#  'drug_disease_140': ('t_18058121_rel_1', '2'),
#  'drug_disease_141': ('t_17391803_rel_0', '2'),
#  'drug_disease_142': ('t_19026757_rel_4', '3'),
#  'drug_disease_143': ('t_19026757_rel_2', '2'),
#  'drug_disease_144': ('t_18303032_rel_6', '2'),
#  'drug_disease_145': ('t_18303032_rel_0', '2'),
#  'drug_disease_146': ('t_18303032_rel_4', '2'),
#  'drug_disease_147': ('t_18303032_rel_2', '2'),
#  'drug_disease_148': ('t_18303032_rel_1', '2'),
#  'drug_disease_149': ('t_18303032_rel_5', '2'),
#  'drug_disease_15': ('t_18640477_rel_11', '3'),
#  'drug_disease_150': ('t_18303032_rel_3', '2'),
#  'drug_disease_151': ('t_17541882_rel_0', '2'),
#  'drug_disease_152': ('t_17541882_rel_1', '2'),
#  'drug_disease_153': ('t_19033289_rel_2', '2'),
#  'drug_disease_154': ('t_17562245_rel_8', '3'),
#  'drug_disease_155': ('t_17562245_rel_0', '3'),
#  'drug_disease_156': ('t_17562245_rel_4', '3'),
#  'drug_disease_157': ('t_17562245_rel_2', '3'),
#  'drug_disease_158': ('t_17562245_rel_6', '3'),
#  'drug_disease_159': ('t_18512713_rel_14', '3'),
#  'drug_disease_16': ('t_18640477_rel_0', '2'),
#  'drug_disease_160': ('t_18512713_rel_12', '3'),
#  'drug_disease_161': ('t_18512713_rel_13', '3'),
#  'drug_disease_162': ('t_18512713_rel_8', '2'),
#  'drug_disease_163': ('t_18512713_rel_9', '3'),
#  'drug_disease_164': ('t_18512713_rel_10', '3'),
#  'drug_disease_165': ('t_18512713_rel_7', '3'),
#  'drug_disease_166': ('t_18512713_rel_2', '2'),
#  'drug_disease_167': ('t_18512713_rel_4', '2'),
#  'drug_disease_168': ('t_18512713_rel_3', '2'),
#  'drug_disease_169': ('t_18512713_rel_1', '2'),
#  'drug_disease_17': ('t_18640477_rel_4', '2'),
#  'drug_disease_170': ('t_18512713_rel_0', '2'),
#  'drug_disease_171': ('t_18205897_rel_1', '2'),
#  'drug_disease_172': ('t_18198174_rel_0', '2'),
#  'drug_disease_173': ('t_18389682_rel_3', '2'),
#  'drug_disease_174': ('t_18389682_rel_0', '2'),
#  'drug_disease_175': ('t_18389682_rel_2', '2'),
#  'drug_disease_176': ('t_17945482_rel_9', '2'),
#  'drug_disease_177': ('t_17945482_rel_0', '3'),
#  'drug_disease_178': ('t_17945482_rel_5', '3'),
#  'drug_disease_179': ('t_17945482_rel_3', '3'),
#  'drug_disease_18': ('t_18640477_rel_8', '2'),
#  'drug_disease_180': ('t_17945482_rel_4', '3'),
#  'drug_disease_181': ('t_18533797_rel_1', '3'),
#  'drug_disease_182': ('t_18533797_rel_2', '2'),
#  'drug_disease_183': ('t_18533797_rel_0', '2'),
#  'drug_disease_184': ('t_18790215_rel_2', '2'),
#  'drug_disease_185': ('t_18790215_rel_0', '2'),
#  'drug_disease_186': ('t_18790215_rel_3', '2'),
#  'drug_disease_187': ('t_18790215_rel_1', '2'),
#  'drug_disease_188': ('t_17697016_rel_2', '3'),
#  'drug_disease_189': ('t_17697016_rel_4', '3'),
#  'drug_disease_19': ('t_18640477_rel_9', '3'),
#  'drug_disease_190': ('t_17697016_rel_6', '2'),
#  'drug_disease_191': ('t_17697016_rel_5', '3'),
#  'drug_disease_192': ('t_17697016_rel_3', '2'),
#  'drug_disease_193': ('t_18713156_rel_4', '3'),
#  'drug_disease_194': ('t_18713156_rel_3', '3'),
#  'drug_disease_195': ('t_18713156_rel_5', '2'),
#  'drug_disease_196': ('t_18713156_rel_0', '3'),
#  'drug_disease_197': ('t_18077493_rel_0', '3'),
#  'drug_disease_198': ('t_18077493_rel_5', '2'),
#  'drug_disease_199': ('t_17547473_rel_0', '2'),
#  'drug_disease_2': ('t_18042885_rel_0', '2'),
#  'drug_disease_20': ('t_18640477_rel_3', '2'),
#  'drug_disease_200': ('t_17547473_rel_9', '2'),
#  'drug_disease_201': ('t_17547473_rel_5', '3'),
#  'drug_disease_202': ('t_17547473_rel_1', '2'),
#  'drug_disease_203': ('t_17547473_rel_3', '2'),
#  'drug_disease_204': ('t_17547473_rel_2', '3'),
#  'drug_disease_205': ('t_17547473_rel_4', '2'),
#  'drug_disease_206': ('t_17726209_rel_1', '2'),
#  'drug_disease_207': ('t_17726209_rel_0', '2'),
#  'drug_disease_208': ('t_18975369_rel_10', '2'),
#  'drug_disease_209': ('t_18975369_rel_9', '2'),
#  'drug_disease_21': ('t_18953065_rel_0', '3'),
#  'drug_disease_210': ('t_18975369_rel_0', '2'),
#  'drug_disease_211': ('t_18975369_rel_8', '2'),
#  'drug_disease_212': ('t_18975369_rel_6', '3'),
#  'drug_disease_213': ('t_18975369_rel_7', '2'),
#  'drug_disease_214': ('t_18975369_rel_5', '3'),
#  'drug_disease_215': ('t_18975369_rel_1', '2'),
#  'drug_disease_216': ('t_18975369_rel_4', '3'),
#  'drug_disease_217': ('t_18975369_rel_3', '3'),
#  'drug_disease_218': ('t_18975369_rel_2', '3'),
#  'drug_disease_219': ('t_17688650_rel_2', '2'),
#  'drug_disease_22': ('t_18953065_rel_2', '3'),
#  'drug_disease_220': ('t_17688650_rel_0', '3'),
#  'drug_disease_221': ('t_17688650_rel_1', '3'),
#  'drug_disease_222': ('t_18609261_rel_0', '3'),
#  'drug_disease_223': ('t_18609261_rel_2', '2'),
#  'drug_disease_224': ('t_18560637_rel_0', '2'),
#  'drug_disease_225': ('t_17291222_rel_0', '3'),
#  'drug_disease_226': ('t_17291222_rel_1', '3'),
#  'drug_disease_227': ('t_17291222_rel_2', '2'),
#  'drug_disease_228': ('t_17291222_rel_3', '2'),
#  'drug_disease_229': ('t_19100448_rel_3', '2'),
#  'drug_disease_23': ('t_18953065_rel_1', '3'),
#  'drug_disease_230': ('t_19100448_rel_4', '2'),
#  'drug_disease_231': ('t_19100448_rel_6', '3'),
#  'drug_disease_232': ('t_19100448_rel_0', '2'),
#  'drug_disease_233': ('t_19100448_rel_8', '2'),
#  'drug_disease_234': ('t_16944312_rel_3', '2'),
#  'drug_disease_235': ('t_16944312_rel_4', '2'),
#  'drug_disease_236': ('t_16944312_rel_1', '3'),
#  'drug_disease_237': ('t_16944312_rel_0', '2'),
#  'drug_disease_238': ('t_17244684_rel_2', '2'),
#  'drug_disease_239': ('t_17244684_rel_1', '2'),
#  'drug_disease_24': ('t_18434457_rel_2', '2'),
#  'drug_disease_240': ('t_17244684_rel_6', '2'),
#  'drug_disease_241': ('t_17244684_rel_3', '3'),
#  'drug_disease_242': ('t_18398094_rel_0', '3'),
#  'drug_disease_243': ('t_18398094_rel_2', '3'),
#  'drug_disease_25': ('t_18434457_rel_5', '2'),
#  'drug_disease_26': ('t_18434457_rel_6', '2'),
#  'drug_disease_27': ('t_18434457_rel_1', '2'),
#  'drug_disease_28': ('t_18434457_rel_0', '2'),
#  'drug_disease_29': ('t_18434457_rel_3', '2'),
#  'drug_disease_3': ('t_18037672_rel_2', '2'),
#  'drug_disease_30': ('t_18434457_rel_4', '2'),
#  'drug_disease_31': ('t_18371953_rel_3', '2'),
#  'drug_disease_32': ('t_18371953_rel_12', '3'),
#  'drug_disease_33': ('t_18371953_rel_0', '2'),
#  'drug_disease_34': ('t_18371953_rel_4', '3'),
#  'drug_disease_35': ('t_18371953_rel_5', '2'),
#  'drug_disease_36': ('t_18371953_rel_8', '3'),
#  'drug_disease_37': ('t_18371953_rel_1', '2'),
#  'drug_disease_38': ('t_18371953_rel_9', '3'),
#  'drug_disease_39': ('t_18371953_rel_11', '3'),
#  'drug_disease_4': ('t_18037672_rel_3', '2'),
#  'drug_disease_40': ('t_18371953_rel_13', '3'),
#  'drug_disease_41': ('t_18371953_rel_2', '2'),
#  'drug_disease_42': ('t_18371953_rel_7', '3'),
#  'drug_disease_43': ('t_18371953_rel_6', '3'),
#  'drug_disease_44': ('t_18371953_rel_10', '3'),
#  'drug_disease_45': ('t_18371953_rel_14', '3'),
#  'drug_disease_46': ('t_17483062_rel_0', '2'),
#  'drug_disease_47': ('t_17483062_rel_3', '2'),
#  'drug_disease_48': ('t_17483062_rel_4', '2'),
#  'drug_disease_49': ('t_18220495_rel_2', '2'),
#  'drug_disease_5': ('t_17237684_rel_2', '3'),
#  'drug_disease_50': ('t_18220495_rel_0', '3'),
#  'drug_disease_51': ('t_18220495_rel_1', '2'),
#  'drug_disease_52': ('t_18220495_rel_3', '3'),
#  'drug_disease_53': ('t_17976209_rel_0', '3'),
#  'drug_disease_54': ('t_18300089_rel_0', '2'),
#  'drug_disease_55': ('t_18300089_rel_8', '3'),
#  'drug_disease_56': ('t_18300089_rel_4', '3'),
#  'drug_disease_57': ('t_18300089_rel_2', '2'),
#  'drug_disease_58': ('t_18300089_rel_1', '2'),
#  'drug_disease_59': ('t_18300089_rel_5', '3'),
#  'drug_disease_6': ('t_17940253_rel_0', '3'),
#  'drug_disease_60': ('t_18300089_rel_7', '2'),
#  'drug_disease_61': ('t_18300089_rel_3', '2'),
#  'drug_disease_62': ('t_18300089_rel_6', '3'),
#  'drug_disease_63': ('t_18923587_rel_0', '3'),
#  'drug_disease_64': ('t_18342498_rel_0', '3'),
#  'drug_disease_65': ('t_18342498_rel_1', '3'),
#  'drug_disease_66': ('t_18452197_rel_13', '2'),
#  'drug_disease_67': ('t_18452197_rel_12', '2'),
#  'drug_disease_68': ('t_18452197_rel_1', '2'),
#  'drug_disease_69': ('t_18452197_rel_0', '2'),
#  'drug_disease_7': ('t_17940253_rel_1', '3'),
#  'drug_disease_70': ('t_18452197_rel_6', '2'),
#  'drug_disease_71': ('t_18452197_rel_19', '3'),
#  'drug_disease_72': ('t_18452197_rel_17', '3'),
#  'drug_disease_73': ('t_18452197_rel_18', '3'),
#  'drug_disease_74': ('t_18452197_rel_3', '2'),
#  'drug_disease_75': ('t_18452197_rel_4', '2'),
#  'drug_disease_76': ('t_18452197_rel_16', '2'),
#  'drug_disease_77': ('t_18452197_rel_14', '2'),
#  'drug_disease_78': ('t_18452197_rel_9', '3'),
#  'drug_disease_79': ('t_18452197_rel_15', '3'),
#  'drug_disease_8': ('t_17940253_rel_2', '2'),
#  'drug_disease_80': ('t_18452197_rel_7', '2'),
#  'drug_disease_81': ('t_18452197_rel_8', '3'),
#  'drug_disease_82': ('t_17167348_rel_0', '2'),
#  'drug_disease_83': ('t_17167348_rel_1', '3'),
#  'drug_disease_84': ('t_17167348_rel_3', '3'),
#  'drug_disease_85': ('t_17340045_rel_1', '3'),
#  'drug_disease_86': ('t_17340045_rel_3', '2'),
#  'drug_disease_87': ('t_17340045_rel_4', '2'),
#  'drug_disease_88': ('t_17340045_rel_0', '2'),
#  'drug_disease_89': ('t_17340045_rel_5', '2'),
#  'drug_disease_9': ('t_17274718_rel_1', '2'),
#  'drug_disease_90': ('t_18164769_rel_2', '3'),
#  'drug_disease_91': ('t_17989313_rel_3', '2'),
#  'drug_disease_92': ('t_17989313_rel_7', '2'),
#  'drug_disease_93': ('t_17989313_rel_8', '3'),
#  'drug_disease_94': ('t_18299079_rel_0', '2'),
#  'drug_disease_95': ('t_18299079_rel_3', '3'),
#  'drug_disease_96': ('t_17668247_rel_3', '2'),
#  'drug_disease_97': ('t_18713852_rel_9', '3'),
#  'drug_disease_98': ('t_18713852_rel_4', '3'),
#  'drug_disease_99': ('t_18713852_rel_17', '2')}

# %%
crowd_percent = dict()
for unit_id, group in results.groupby("unit_id"):
    if group.iloc[0]["match"] == 1: # top answer matched experts
        crowd_percent[unit_id] = group.iloc[0]["percent_agreement"]

# %%
len(crowd_percent)
# Out:
# 44

# %%
crowd_percent
# Out:
# {698757975: 0.9073112857778437,
#  698757978: 0.71011638946517108,
#  698757979: 0.81216402835001533,
#  698757980: 0.60749605348686042,
#  698757981: 0.49883542577969664,
#  698757982: 1.0,
#  698757983: 1.0,
#  698757985: 1.0,
#  698757986: 0.40427387207827509,
#  698757987: 0.71855520738569367,
#  698757988: 0.40934627170582227,
#  698757990: 1.0,
#  698757992: 0.51133979767842985,
#  698757993: 1.0,
#  698757994: 1.0,
#  698757996: 0.8992005160933576,
#  698757997: 0.90417195144047835,
#  698757998: 1.0,
#  698757999: 0.69971010475497497,
#  698758000: 0.59016806420268475,
#  698758002: 1.0,
#  698758003: 1.0,
#  698758004: 1.0,
#  698758005: 0.71147506732287125,
#  698758009: 0.91244434813443132,
#  698758012: 1.0,
#  698758013: 1.0,
#  698758015: 1.0,
#  698758016: 1.0,
#  698758018: 0.71011638946517108,
#  698758022: 1.0,
#  698758023: 0.80369717253871709,
#  698758024: 0.62099325119046267,
#  698758025: 0.89894090063869347,
#  698936313: 0.90453407010568643,
#  698936583: 1.0,
#  698936792: 0.88580694522159154,
#  698937471: 1.0,
#  698937671: 1.0,
#  698937904: 1.0,
#  698939052: 0.80056621201761025,
#  698939741: 0.81352850682951838,
#  698942095: 1.0,
#  698942663: 0.81568094371356825}

# %%
expert_v = []
crowd_v = []

two = []
three = []

a_two = []
a_three = []

for unit_id, percent in crowd_percent.items():
    toby_id = id_mapping[str(unit_id)]
    
    if toby_id in raw_toby_mapping:
        expert_v.append(raw_toby_mapping[toby_id][1])
        crowd_v.append(percent)
        
        if raw_toby_mapping[toby_id][1] == "2":
            two.append(percent)
            a_two.append((unit_id, percent))
        else:
            three.append(percent)
            a_three.append((unit_id, percent))

# %%
print len(two) + len(three)
# Out:
# 44

# %%
a_two
# Out:
# [(698758018, 0.71011638946517108),
#  (698758023, 0.80369717253871709),
#  (698758024, 0.62099325119046267),
#  (698758025, 0.89894090063869347),
#  (698936583, 1.0),
#  (698939052, 0.80056621201761025),
#  (698937904, 1.0),
#  (698757975, 0.9073112857778437),
#  (698757978, 0.71011638946517108),
#  (698757979, 0.81216402835001533),
#  (698757980, 0.60749605348686042),
#  (698757981, 0.49883542577969664),
#  (698757983, 1.0),
#  (698757986, 0.40427387207827509),
#  (698757987, 0.71855520738569367),
#  (698757988, 0.40934627170582227),
#  (698757993, 1.0),
#  (698757996, 0.8992005160933576),
#  (698757997, 0.90417195144047835),
#  (698757998, 1.0),
#  (698757999, 0.69971010475497497),
#  (698758002, 1.0),
#  (698942663, 0.81568094371356825)]

# %%
a_three
# Out:
# [(698758016, 1.0),
#  (698758022, 1.0),
#  (698942095, 1.0),
#  (698936313, 0.90453407010568643),
#  (698939741, 0.81352850682951838),
#  (698937671, 1.0),
#  (698936792, 0.88580694522159154),
#  (698757982, 1.0),
#  (698757985, 1.0),
#  (698757990, 1.0),
#  (698757992, 0.51133979767842985),
#  (698757994, 1.0),
#  (698758000, 0.59016806420268475),
#  (698758003, 1.0),
#  (698758004, 1.0),
#  (698758005, 0.71147506732287125),
#  (698758009, 0.91244434813443132),
#  (698937471, 1.0),
#  (698758012, 1.0),
#  (698758013, 1.0),
#  (698758015, 1.0)]

# %%
two
# Out:
# [0.71011638946517108,
#  0.80369717253871709,
#  0.62099325119046267,
#  0.89894090063869347,
#  1.0,
#  0.80056621201761025,
#  1.0,
#  0.9073112857778437,
#  0.71011638946517108,
#  0.81216402835001533,
#  0.60749605348686042,
#  0.49883542577969664,
#  1.0,
#  0.40427387207827509,
#  0.71855520738569367,
#  0.40934627170582227,
#  1.0,
#  0.8992005160933576,
#  0.90417195144047835,
#  1.0,
#  0.69971010475497497,
#  1.0,
#  0.81568094371356825]

# %%
three
# Out:
# [1.0,
#  1.0,
#  1.0,
#  0.90453407010568643,
#  0.81352850682951838,
#  1.0,
#  0.88580694522159154,
#  1.0,
#  1.0,
#  1.0,
#  0.51133979767842985,
#  1.0,
#  0.59016806420268475,
#  1.0,
#  1.0,
#  0.71147506732287125,
#  0.91244434813443132,
#  1.0,
#  1.0,
#  1.0,
#  1.0]

# %%
two = pd.Series(two)
two
# Out:
# 0     0.710116
# 1     0.803697
# 2     0.620993
# 3     0.898941
# 4     1.000000
# 5     0.800566
# 6     1.000000
# 7     0.907311
# 8     0.710116
# 9     0.812164
# 10    0.607496
# 11    0.498835
# 12    1.000000
# 13    0.404274
# 14    0.718555
# 15    0.409346
# 16    1.000000
# 17    0.899201
# 18    0.904172
# 19    1.000000
# 20    0.699710
# 21    1.000000
# 22    0.815681
# dtype: float64

# %%
print len(two)
print len(three)
# Out:
# 23
# 21

# %%
two.mean()
# Out:
# 0.79222504242967018

# %%
two.std()
# Out:
# 0.18864050491398315

# %%
three = pd.Series(three)

# %%
three.mean()
# Out:
# 0.92044270473786738

# %%
three.std()
# Out:
# 0.14520200159773386

# %%
d = {"crowd_v": crowd_v, "expert_group": expert_v}
temp = pd.DataFrame(d)

# %%
temp
# Out:
#      crowd_v expert_group
# 0   1.000000            3
# 1   0.710116            2
# 2   1.000000            3
# 3   0.803697            2
# 4   0.620993            2
# 5   0.898941            2
# 6   1.000000            3
# 7   0.904534            3
# 8   1.000000            2
# 9   0.800566            2
# 10  0.813529            3
# 11  1.000000            2
# 12  1.000000            3
# 13  0.907311            2
# 14  0.885807            3
# 15  0.710116            2
# 16  0.812164            2
# 17  0.607496            2
# 18  0.498835            2
# 19  1.000000            3
# 20  1.000000            2
# 21  1.000000            3
# 22  0.404274            2
# 23  0.718555            2
# 24  0.409346            2
# 25  1.000000            3
# 26  0.511340            3
# 27  1.000000            2
# 28  1.000000            3
# 29  0.899201            2
# 30  0.904172            2
# 31  1.000000            2
# 32  0.699710            2
# 33  0.590168            3
# 34  1.000000            2
# 35  1.000000            3
# 36  1.000000            3
# 37  0.711475            3
# 38  0.912444            3
# 39  1.000000            3
# 40  1.000000            3
# 41  1.000000            3
# 42  0.815681            2
# 43  1.000000            3

# %%
temp.boxplot(by="expert_group")
